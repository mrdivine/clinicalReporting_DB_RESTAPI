# %% [markdown]
# # Collect Driver Genes from Various Sources
#
# Collect the various driver genes from the various sources listed in the README.md, placing them into
# the predifined json-schema outlined in "driversValidationSchemaLight.json". Start
# at the top of the list in the README, and just collect...
#
# When collecting, try to stay with a particular column naming
#
# "gene_symbol","driver_type","pmid","source_name"

# %%
import pandas as pd
import os
import datetime
import numpy as np

# %%
import lxml.etree as ET
import codecs
import subprocess
from rdkit import Chem
import gzip
import requests
from functools import reduce

# %%
def combine_cols(series, colname):
    ret_val = np.nan
    for col in colname:
        if not pd.isnull(series[col]):
            ret_val = series[col]
            break
    return ret_val

# %%
#set data path with your own
data_path = "/Users/Heisenberg/DockerStation/clinicalReporting_DB_RESTAPI/data"

# %%
# %cd ../data/
# Out:
# /Users/Heisenberg/DockerStation/clinicalReporting_DB_RESTAPI/data

# %% [markdown]
# # Download gene data

# %%
# %cd /Users/Heisenberg/DockerStation/clinicalReporting_01/Data

# %%
HGNC_DOWNLOAD = "ftp://ftp.ebi.ac.uk/pub/databases/genenames/new/tsv/hgnc_complete_set.txt"
UNIPROT_DOWNLOAD = "http://www.uniprot.org/uniprot/?query=reviewed:yes+AND+organism:9606&format=tab&compress=yes&columns=id,entry%20name,reviewed,protein%20names,genes,organism,length,sequence,ec,feature(ACTIVE%20SITE),feature(BINDING%20SITE),comment(TISSUE%20SPECIFICITY),go(biological%20process),go(molecular%20function),go(cellular%20component),go-id,comment(BIOTECHNOLOGY),comment(DISEASE),comment(PHARMACEUTICAL),feature(MUTAGENESIS),comment(DISRUPTION%20PHENOTYPE),last-modified,created,database(CCDS),database(EMBL),database(RefSeq),database(HGNC)"

# %%
genes = pd.read_csv(HGNC_DOWNLOAD, sep="\t").rename(columns={'symbol': 'gene_symbol'})
# Out:
# /Users/Heisenberg/anaconda/envs/clinicalreporting/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (32,34,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
genes["hgnc_id"] = genes["hgnc_id"].str.replace("HGNC:", "")

# %%
gene_synonyms = [(s["hgnc_id"], x)
                 for i, s in genes[["hgnc_id", "alias_symbol"]].dropna(subset=["alias_symbol"]).iterrows()
                 for x in s["alias_symbol"].split("|") if x not in genes["gene_symbol"].tolist()]

# %%
gene_synonyms += [(s["hgnc_id"], x)
                  for i, s in genes[["hgnc_id", "prev_symbol"]].dropna(subset=["prev_symbol"]).iterrows()
                  for x in s["prev_symbol"].split("|") if x not in genes["gene_symbol"].tolist()]

# %%
gene_synonym_df = pd.concat([genes[["hgnc_id", "gene_symbol"]],
                             pd.DataFrame(gene_synonyms, columns=["hgnc_id", "gene_symbol"])])

# %%
all_genes = genes[['hgnc_id', 'gene_symbol', 'name', 'status', 'locus_group', 'locus_type',
                   'gene_family', 'alias_symbol', 'prev_symbol', 'location', 'uniprot_ids',
                   'entrez_id', 'ensembl_gene_id', 'date_approved_reserved', 'date_modified',
                   'date_symbol_changed']].set_index('hgnc_id', drop=False).fillna('null').to_dict('index')

# %%
genes2entrez = genes[["hgnc_id", "entrez_id"]].dropna()

# %%
genes2uniprot = genes[["hgnc_id", "uniprot_ids"]].dropna()

# %%
#name some global variables
columns_to_db = ["hgnc_id", "gene_symbol","driver_type","pmid","source_name"]
source_container = {}

# %% [markdown]
# # Vogelstein et al.

# %%
path_name = os.path.join(data_path,'Vogelstein_CancerGenomeLandscape_Science_2013.csv')
vogelstein_df = pd.read_csv(path_name,delimiter=';')
vogelstein_pmid = '23539594'
vogelstein_name = "Vogelstein"
vogelstein_df = vogelstein_df.assign(pmid=vogelstein_pmid,source_name=vogelstein_name)
# correct names for later mergin'
vogelstein_df = vogelstein_df.rename(index=str,columns={"Gene Symbol":"gene_symbol","Classification*":"driver_type"})
vogelstein_df = vogelstein_df.merge(gene_synonym_df)

vogelstein_df=vogelstein_df[columns_to_db]
vogelstein_df['driver_type'].unique()

source_container[vogelstein_name]=vogelstein_df

# %% [markdown]
# # Rubio-Perez et al.

# %%
path_name = os.path.join(data_path,'Drivers_type_role.tsv')
rubiop_df = pd.read_csv(path_name,delimiter='\t',comment='#')
rubiop_pmid = "25759023"
rubiop_name = "Rubio-Perez"
rubiop_df = rubiop_df.assign(pmid=rubiop_pmid,source_name=rubiop_name)
rubiop_df = rubiop_df.rename(index=str,columns={"geneHGNCsymbol":"gene_symbol","Driver_type":"driver_type"})
rubiop_df = rubiop_df.merge(gene_synonym_df)

rubiop_df['Role'].unique()
rubiop_df['driver_type'].unique()
mapper = dict(zip(rubiop_df['Role'].unique(),["Oncogene","TSG","Unknown","Oncogene"]))
rubiop_df["driver_type"]=rubiop_df["Role"].map(mapper)
# rubiop_df.loc[rubiop_df['Role']=='A']

rubiop_df= rubiop_df[columns_to_db]

source_container[rubiop_name]=rubiop_df

# %% [markdown]
# # Uniprot

# %%
oncogene_path_name = os.path.join(data_path,'uniprot-keyword%3A%22Proto-oncogene+%5BKW-0656%5D%22.tab')
tsg_path_name = os.path.join(data_path,'uniprot-keyword%3A%22Tumor+suppressor+%5BKW-0043%5D%22.tab')

uniprot_oncogene_df = pd.read_csv(oncogene_path_name,'\t')
uniprot_oncogene_df["driver_type"]="Oncogene"
uniprot_tsg_df = pd.read_csv(tsg_path_name,'\t')
uniprot_tsg_df["driver_type"]="TSG"

uniprot_df = pd.concat([uniprot_tsg_df,uniprot_oncogene_df],axis=0)
uniprot_df["gene_symbol"]=uniprot_df["Gene names"].apply(lambda x: x.split(" ")[0])

uniprot_df = uniprot_df.merge(genes2uniprot, left_on="Entry", right_on="uniprot_ids").drop("uniprot_ids", axis=1)

uniprot_name = "Uniprot"
uniprot_pmid = "14681372"
uniprot_df = uniprot_df.assign(pmid=uniprot_pmid,source_name=uniprot_name)

uniprot_df = uniprot_df[columns_to_db]

source_container[uniprot_name] = uniprot_df

# %% [markdown]
# # Cosmic Census

# %%
path_name = os.path.join(data_path,'Census_allTue Mar 14 14_33_17 2017.tsv')
cosmic_df = pd.read_csv(path_name,"\t")
cosmic_name = "Cosmic"
cosmic_pmid = "14993899"
cosmic_df = cosmic_df.assign(source_name=cosmic_name,pmid=cosmic_pmid)

cosmic_df["Role in Cancer"].unique()
mapper = dict(zip(cosmic_df["Role in Cancer"].unique(),["TSG","Oncogene","Unknown","Oncogene/TSG"]))

cosmic_df["driver_type"]=cosmic_df["Role in Cancer"].map(mapper)
cosmic_df = cosmic_df.rename(index=str, columns={"Gene Symbol":"gene_symbol"})
cosmic_df = cosmic_df.merge(genes2entrez, left_on="Entrez GeneId", right_on="entrez_id").drop("entrez_id", axis=1)
cosmic_df = cosmic_df[columns_to_db]

source_container[cosmic_name]=cosmic_df

# %% [markdown]
# # TSgene

# %%
tsgene_pathname = os.path.join(data_path,'Human_TSGs.txt')
tsgene_df = pd.read_csv(tsgene_pathname,delimiter="\t")
tsgene_df[:1]

tsgene_name = "TSgene"
tsgene_pmid = "23066107"

tsgene_df= tsgene_df.assign(source_name=tsgene_name,pmid=tsgene_pmid,driver_type="TSG")
tsgene_df = tsgene_df.rename(index=str,columns={"GeneSymbol":"gene_symbol"})
tsgene_df = tsgene_df.merge(genes2entrez, left_on="GeneID", right_on="entrez_id").drop("entrez_id", axis=1)
tsgene_df = tsgene_df[columns_to_db]

source_container[tsgene_name]=tsgene_df

# %% [markdown]
# # Putting it all together

# %%
# check the keys to see if it all went down according to plan
source_container.keys()
# Out:
# dict_keys(['Vogelstein', 'Rubio-Perez', 'TSgene', 'Cosmic', 'Uniprot'])

# %%
# put the containers together 
df_final = reduce(lambda left,right: pd.concat([left,right],ignore_index=True), source_container.values())
# some duplicates showed up??
df_final.drop_duplicates(inplace=True)

# this seems a little too hacked for my tast. Don't know, feel free to change it and let me know what you did
df_scored = pd.merge(df_final,df_final.groupby("gene_symbol").count()["pmid"].to_frame(),left_on="gene_symbol",right_index=True)
df_scored = df_scored.rename(index=str,columns=dict(zip(["pmid_x","pmid_y"],["pmid","score"])))

# %%
group_cols = ["hgnc_id"]
exclude_cols = group_cols + ["gene_symbol"]
groups = df_scored.groupby(["hgnc_id"])
for n, g in groups:
    all_genes[str(n)]['cancer'] = g[[c for c in g.columns if c not in exclude_cols]].to_dict('records')

# %% [markdown]
# # Do a little "speed vali-dating"

# %%
# only have 5 pmids i.e. can't be seven like when there were duplicates still in the dataframe
df_scored["score"].unique()
# Out:
# array([4, 2, 5, 3, 1])

# %%
df_final["gene_symbol"].unique()
# Out:
# array(['ABL1', 'ACVR1B', 'AKT1', ..., 'PTTG1', 'PTTG3P', 'STYK1'], dtype=object)

# %%
# typical query
df_scored.loc[df_scored["gene_symbol"]=="EGFR"]
# Out:
#       hgnc_id gene_symbol driver_type      pmid  source_name  score
# 36       3236        EGFR    Oncogene  23539594   Vogelstein      4
# 279      3236        EGFR    Oncogene  25759023  Rubio-Perez      4
# 1989     3236        EGFR     Unknown  14993899       Cosmic      4
# 2689     3236        EGFR    Oncogene  14681372      Uniprot      4

# %%
all_genes['3236']
# Out:
# {'alias_symbol': 'ERBB1',
#  'cancer': [{'driver_type': 'Oncogene',
#    'pmid': '23539594',
#    'score': 4,
#    'source_name': 'Vogelstein'},
#   {'driver_type': 'Oncogene',
#    'pmid': '25759023',
#    'score': 4,
#    'source_name': 'Rubio-Perez'},
#   {'driver_type': 'Unknown',
#    'pmid': '14993899',
#    'score': 4,
#    'source_name': 'Cosmic'},
#   {'driver_type': 'Oncogene',
#    'pmid': '14681372',
#    'score': 4,
#    'source_name': 'Uniprot'}],
#  'date_approved_reserved': '1986-01-01',
#  'date_modified': '2017-03-24',
#  'date_symbol_changed': 'null',
#  'ensembl_gene_id': 'ENSG00000146648',
#  'entrez_id': 1956.0,
#  'gene_family': 'Erb-b2 receptor tyrosine kinases',
#  'gene_symbol': 'EGFR',
#  'hgnc_id': '3236',
#  'location': '7p11.2',
#  'locus_group': 'protein-coding gene',
#  'locus_type': 'gene with protein product',
#  'name': 'epidermal growth factor receptor',
#  'prev_symbol': 'ERBB',
#  'status': 'Approved',
#  'uniprot_ids': 'P00533'}

# %% [markdown]
# # Target stuff

# %%
drug_data_containers = {}

# %% [markdown]
# ## DrugBank

# %%
DRUGBANK_DOWNLOAD = "http://www.drugbank.ca/releases/latest/downloads/all-full-database"
DRUGBANK_STRUCTURES_DOWNLOAD = "http://www.drugbank.ca/releases/latest/downloads/all-structures"
DRUGBANK_XREFS_DOWNLAOD = "http://www.drugbank.ca/releases/latest/downloads/all-drug-links"
DRUGBANK_USER = "c.schaerfe@gmail.com"
DRUGBANK_PASSWORD = "themirrorcracked"

# %%
DRUGBANK_FILE = os.path.join(data_path, "drugbank.xml.zip")
DRUGBANK_SDF_FILE = os.path.join(data_path, "drugbank_molecules.sdf.zip")
DRUGBANK_XREF_FILE = os.path.join(data_path, "drugbank_xrefs.csv.zip")

# %%
DRUGBANK_FILE
# Out:
# '/Users/Heisenberg/DockerStation/clinicalReporting_DB_RESTAPI/data/drugbank.xml.zip'

# %%
i = 1
exit_code_xml, exit_code_sdf, exit_code_xref = 1, 1, 1
while exit_code_xml + exit_code_sdf + exit_code_xref > 0 and i < 11:
    print("trying download now for round number {}".format(i))
    
    if exit_code_xml > 0:
        exit_code_xml = subprocess.call(['curl', '-L', '-H', 
                                         '"Accept: application/xml"', 
                                         '-o', DRUGBANK_FILE,
                                         '-u', DRUGBANK_USER + ':' + DRUGBANK_PASSWORD,
                                         DRUGBANK_DOWNLOAD])
 
        print("xml", exit_code_xml)
    if exit_code_sdf > 0:
        exit_code_sdf = subprocess.call(['curl', '-L', 
                                         '-o', DRUGBANK_SDF_FILE,
                                         '-u', DRUGBANK_USER + ':' + DRUGBANK_PASSWORD,
                                         DRUGBANK_STRUCTURES_DOWNLOAD])
        print("sdf", exit_code_sdf)
    if exit_code_xref > 0:
        exit_code_xref= subprocess.call(['curl', '-L',
                                         '-o', DRUGBANK_XREF_FILE,
                                         '-u', DRUGBANK_USER + ':' + DRUGBANK_PASSWORD,
                                         DRUGBANK_XREFS_DOWNLAOD])
 
        print("xref", exit_code_xref)
    i += 1
# Out:
# trying download now for round number 1
# xml 0
# sdf 0
# xref 0

# %%
if exit_code_xml == 0:
    exit_code_xml = subprocess.call("unzip -p " + DRUGBANK_FILE +" \*.xml | cat > " + DRUGBANK_FILE.replace(".zip", ""), shell=True)
if exit_code_sdf == 0:
    exit_code_sdf = subprocess.call("unzip -p " + DRUGBANK_SDF_FILE +" \*.sdf | cat > " + DRUGBANK_SDF_FILE.replace(".zip", ""), shell=True)
if exit_code_xref == 0:
    exit_code_xref = subprocess.call("unzip -p " + DRUGBANK_XREF_FILE +" \*.csv | cat > " + DRUGBANK_XREF_FILE.replace(".zip", ""), shell=True)

# %%
print(exit_code_sdf)
# Out:
# 0

# %%
# i = 0
# exit_code_xml, exit_code_sdf, exit_code_xref = 1, 1, 1
# while exit_code_sdf  > 0 or i < 10:
#     if exit_code_sdf > 0:
#         exit_code_sdf = subprocess.call(['curl', '-L', 
#                                          '-o', DRUGBANK_SDF_FILE,
#                                          '-u', DRUGBANK_USER + ':' + DRUGBANK_PASSWORD,
#                                          DRUGBANK_STRUCTURES_DOWNLOAD])
#         if exit_code_sdf == 0:
#             exit_code_sdf = subprocess.call("unzip -p " + DRUGBANK_SDF_FILE +" \*.sdf | cat > " + DRUGBANK_SDF_FILE.replace(".zip", ""), shell=True)
#         print("sdf", exit_code_sdf)
#     i += 1
#     print("trying now for round number {}".format(i))

# %%
print( exit_code_xml, exit_code_sdf, exit_code_xref )
# Out:
# 0 0 0

# %% [markdown]
# Reading the drug molecules

# %%
DRUGBANK_FILE = DRUGBANK_FILE.replace(".zip", "")
DRUGBANK_SDF_FILE = DRUGBANK_SDF_FILE.replace(".zip", "")
DRUGBANK_XREF_FILE = DRUGBANK_XREF_FILE.replace(".zip", "")

# %%
DRUGBANK_SDF_FILE
# Out:
# '/Users/Heisenberg/DockerStation/clinicalReporting_DB_RESTAPI/data/drugbank_molecules.sdf'

# %%
drug_smiles = {}
structures = Chem.SDMolSupplier(DRUGBANK_SDF_FILE)
for s in structures:
    if s is not None:
        db_id = s.GetPropsAsDict().get("DRUGBANK_ID")
        smi = Chem.MolToSmiles(s)
        drug_smiles[db_id] = smi
drugbank2smiles = pd.DataFrame(list(drug_smiles.items()), columns=["drugbank_id", "SMILES"])

# %%
drugbank2smiles
# Out:
#      drugbank_id                                             SMILES
# 0        DB07235   CNc1nccc(-c2ccc(C(=O)NC(CN)Cc3ccc(Cl)cc3Cl)s2)n1
# 1        DB04066                               O=C(O)C=Cc1ccc(O)cc1
# 2        DB08327                                O=C(O)Cc1cc(O)ccc1O
# 3        DB01087                        COc1cc(NC(C)CCCN)c2ncccc2c1
# 4        DB05521  CCCC(NC(=O)C1C2CCCC2CN1C(=O)C(NC(=O)C(NC(=O)c1...
# 5        DB02333  O=c1ccn(C2CC(O)C(COP(=O)(O)OP(=O)(O)OP(=O)(O)O...
# 6        DB04669       Brc1cccc(-c2cc(NCc3ccncc3)[n+]3[nH]cnc3n2)c1
# 7        DB03575                       c1ccc(C2(N3CCCCC3)CCCCC2)cc1
# 8        DB07617                              CNCc1ccc(-c2cccnc2)o1
# 9        DB07704     COc1ccc(CCc2c3nc[nH]c3cc3c(=O)[nH]c(N)nc23)cc1
# 10       DB00445  COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)CC(O)(C(=...
# 11       DB02607       Nc1ncnc2c1ncn2C1OC(COC(=O)CP(=O)(O)O)C(O)C1O
# 12       DB12694  CC(C)N(Cc1ccccc1)C(=O)CN1C(=O)C(Cc2c[nH]c3cccc...
# 13       DB07305           O=C(O)c1ccc(-c2ccc([N+](=O)[O-])cc2Cl)o1
# 14       DB07859        Clc1ccc(C2(c3ccc(-c4cn[nH]c4)cc3)CCNCC2)cc1
# 15       DB02928                         Nc1cc(CC(N)C(=O)O)c(O)cc1O
# 16       DB04737                                    N#CC(O)c1ccccc1
# 17       DB04650                         O=C(O)CCCCC1SCC2NC(=O)NC21
# 18       DB13012             C=C1CCC2C(CN)C(C3(C)CCC(O)CC3CO)CCC12C
# 19       DB12004  COc1cc(OC)c(C=CS(=O)(=O)Cc2ccc(OC)c(OP(=O)(O)O...
# 20       DB08008                Cc1cc(Nc2ccc(C(F)(F)F)cc2)n2ncnc2n1
# 21       DB12969                            COC1C(O)C(O)C(O)C(O)C1O
# 22       DB12285  CN1C(N)=NC(C)(c2cc(NC(=O)c3ccc(F)cn3)ccc2F)CS1...
# 23       DB01778                  Cn1c(=O)c2[nH]c(=N)[nH]c2n(C)c1=O
# 24       DB02380                   O=c1[nH]cnc2c1ncn2C1CC(O)C(CO)O1
# 25       DB09221         NCCC(=O)[N-]C(Cc1cnc[nH]1)C(=O)[O-].[Zn+2]
# 26       DB01301  CN(C)C1C(O)=C(C(=O)NCN2CCCC2)C(=O)C2(O)C(O)=C3...
# 27       DB01338  CC(=O)OC1CC2CCC3C(CCC4(C)C3CC(N3CC[N+](C)(C)CC...
# 28       DB04383                                        CC(C)C(N)CO
# 29       DB07997                       CNCCNS(=O)(=O)c1cccc2cnccc12
# ...          ...                                                ...
# 8517     DB05239  O=C(c1ccc(F)c(F)c1Nc1ccc(I)cc1F)N1CC(O)(C2CCCC...
# 8518     DB07273             Cc1cc(S(=O)(=O)N2CCCC2C(=O)O)c(N)cc1Cl
# 8519     DB06899  CCc1nc(N)nc(N)c1-c1ccc2c(c1)N(CCNC(C)=O)C(=O)C...
# 8520     DB09182              CCC(=O)N(c1ccccc1)C1CCN(Cc2ccccc2)CC1
# 8521     DB12183  CNC(=O)CN1CCC(Oc2cc3c(Nc4cccc(Cl)c4F)ncnc3cc2O...
# 8522     DB04798              CC(C)(C)c1snc([O-])c1CC([NH3+])C(=O)O
# 8523     DB06810  COC(C(=O)C(O)C(C)O)C1Cc2cc3cc(OC4CC(OC5CC(O)C(...
# 8524     DB04778               CC(NC(NCC(O)O)Nc1ccc(CN)cc1)c1ccccc1
# 8525     DB01742                                  CC(=O)N1CCCC(C)C1
# 8526     DB00417        CC1(C)SC2C(NC(=O)COc3ccccc3)C(=O)N2C1C(=O)O
# 8527     DB02887  Cc1cn(C2C=CC(COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O2)...
# 8528     DB03444               O=C1Nc2cc(Br)ccc2C1=C1Nc2ccccc2C1=NO
# 8529     DB01725      N=C(N)c1ccc2[nH]c(-c3cccc(-c4ccccc4)c3O)nc2c1
# 8530     DB08130          NCCNc1nnc(-c2ccc(F)c(F)c2Nc2ccc(I)cc2F)o1
# 8531     DB12111                               Clc1cncc(N2CCNCC2)n1
# 8532     DB08897  O=C(OC1C[N+]2(CCCOc3ccccc3)CCC1CC2)C(O)(c1cccs...
# 8533     DB11825                        CCC1=CC2C(C1)CC2(CN)CC(=O)O
# 8534     DB00869            CCNC1CC(C)S(=O)(=O)c2sc(S(N)(=O)=O)cc21
# 8535     DB03721            CC(=O)NC1C(O)CC(O)(C(=O)O)OC1C(O)C(O)CO
# 8536     DB12081      CC12CCC(=O)C=C1CCC1C2=CCC2(C)C1CCC2(O)C(=O)CO
# 8537     DB12782   OC1(c2ncccn2)CC2CCC(C1)N2C(c1ccccc1Cl)c1ccccc1Cl
# 8538     DB12464          COc1cc(CNCCC2CCOCC2)ccc1Oc1cnc(C(N)=O)cn1
# 8539     DB05186             CC(C)=CCCC(C)=CCNCCNC1C2CC3CC(C2)CC1C3
# 8540     DB07133        Cc1cccc(CNC(=O)C2CCCN2C(=O)C(N)Cc2ccccc2)c1
# 8541     DB04316                         O=C(NO)NC(Cc1ccccc1)C(=O)O
# 8542     DB03845  Cc1cn(C2CC(N=[N+]=[N-])C(COP(=O)([O-])OP(=O)([...
# 8543     DB12506                              N=c1nn[nH]n1-c1ccccc1
# 8544     DB02637                              O=C([O-])CC(=O)C(=O)O
# 8545     DB08288                       CC(C)OC(=O)C(O)C(N)CC1CCCCC1
# 8546     DB08682        CC1=C(C(=O)Nc2ccc(Cl)c(C(=O)OC(C)C)c2)SCCO1
#
# [8547 rows x 2 columns]

# %%
def extract_gene_info(target, drugbank_id):
    target_id = target.find('{http://www.drugbank.ca}id').text
    target_name = target.find('{http://www.drugbank.ca}name').text
    target_organism = target.find('{http://www.drugbank.ca}organism').text

    target_action = b''
    if target.find('{http://www.drugbank.ca}actions') is not None:
        target_action = b'|'.join([act.text.encode('utf-8') for act in
                                  target.find('{http://www.drugbank.ca}actions').
                                  findall('{http://www.drugbank.ca}action')])
    target_known_action = target.find('{http://www.drugbank.ca}known-action').text

    gene_symbol = ""
    hgnc_id = ""
    if target.find('{http://www.drugbank.ca}polypeptide') is not None:
        gene_symbol = target.find('{http://www.drugbank.ca}polypeptide').\
            find('{http://www.drugbank.ca}gene-name').text
        if target.find('{http://www.drugbank.ca}polypeptide').\
                find('{http://www.drugbank.ca}external-identifiers') is not None:
            for external in target.find('{http://www.drugbank.ca}polypeptide').\
                    find('{http://www.drugbank.ca}external-identifiers').\
                    findall('{http://www.drugbank.ca}external-identifier'):
                if external.find('{http://www.drugbank.ca}resource').text ==\
                        "HUGO Gene Nomenclature Committee (HGNC)":
                    hgnc_id = external.find('{http://www.drugbank.ca}identifier').text

    refs = []
    try:
        if target.find('{http://www.drugbank.ca}references') is not None:
            if target.find('{http://www.drugbank.ca}references').\
                    find('{http://www.drugbank.ca}articles') is not None:
                for article in target.find('{http://www.drugbank.ca}references').\
                        find('{http://www.drugbank.ca}articles').\
                        findall('{http://www.drugbank.ca}article'):
                    pmid = article.find('{http://www.drugbank.ca}pubmed-id').text
                    if pmid is not None:
                        refs.append(pmid)
        refs = "|".join(refs)
    except:
        print(drugbank_id)
        print( refs, len(refs))

    row = [drugbank_id, target_id, target_name, target_organism,
           target_action, target_known_action, gene_symbol, hgnc_id, refs]
    row = [r or "" for r in row]
    return row

# %%
DRUGBANK_FILE
# Out:
# '/Users/Heisenberg/DockerStation/clinicalReporting_DB_RESTAPI/data/drugbank.xml'

# %%
tree = ET.parse(DRUGBANK_FILE)
root = tree.getroot()
version = root.attrib.get('version')

drug_synonyms = []
drug_atc = {}
cancer_drugs = {}
lists = []
for record in root.iterfind('{http://www.drugbank.ca}drug'):
    if len(record.find('{http://www.drugbank.ca}drugbank-id')) == 1:
        drugbank_id = record.find('{http://www.drugbank.ca}drugbank-id').text
    else:
        drugbank_id = [x.text for x in record.findall('{http://www.drugbank.ca}drugbank-id')
                       if x.attrib.get('primary', 'false') == 'true'][0]
    
    create_date = record.attrib.get('created')
    update_date = record.attrib.get('updated')
    drug_type = record.attrib.get('type')

    drug_name = record.find('{http://www.drugbank.ca}name').text.lower()
    
    drug_synonyms += [(drugbank_id, syn.text.encode('utf-8').lower()) for syn in record.\
                       find('{http://www.drugbank.ca}synonyms').\
                       findall('{http://www.drugbank.ca}synonym')]
    
    groups = b'|'.join([group.text.encode('utf-8') for group in record.\
                           find('{http://www.drugbank.ca}groups').\
                           findall('{http://www.drugbank.ca}group')])
    
    atc_code_list = []
    is_cancer_drug = 0
    if record.find('{http://www.drugbank.ca}atc-codes') is not None:
        atc_code_list = []
        for atc_code in record.find('{http://www.drugbank.ca}atc-codes').\
                findall('{http://www.drugbank.ca}atc-code'):
            atc_code_list.append(atc_code.attrib.get('code'))
            if atc_code.attrib.get('code').startswith('L01'):
                is_cancer_drug = 1
                cancer_drugs[drugbank_id] = True
            else:
                cancer_drugs[drugbank_id] = False
        drug_atc[drugbank_id] = "|".join(atc_code_list) 
    
    drugbank_data = [drug_name, create_date, update_date, drug_type, is_cancer_drug, groups]
    # extract targets
    if record.find('{http://www.drugbank.ca}targets') is not None:
        for target in record.find('{http://www.drugbank.ca}targets').\
                findall('{http://www.drugbank.ca}target'):
            target_info = extract_gene_info(target, drugbank_id)
            row = target_info + ['target', version]
            lists.append(row + drugbank_data)
    # extract enzymes
    if record.find('{http://www.drugbank.ca}enzymes') is not None:
        for enzyme in record.find('{http://www.drugbank.ca}enzymes').\
                findall('{http://www.drugbank.ca}enzyme'):
            row = extract_gene_info(enzyme, drugbank_id) + ['enzyme', version]
            lists.append(row + drugbank_data)
    # extract carriers
    if record.find('{http://www.drugbank.ca}carriers') is not None:
        for carrier in record.find('{http://www.drugbank.ca}carriers').\
                findall('{http://www.drugbank.ca}carrier'):
            row = extract_gene_info(carrier, drugbank_id) + ['carrier', version]
            lists.append(row + drugbank_data)
    # extract transporters
    if record.find('{http://www.drugbank.ca}transporters') is not None:
        for transporter in record.find('{http://www.drugbank.ca}transporters').\
                findall('{http://www.drugbank.ca}transporter'):
            row = extract_gene_info(transporter, drugbank_id) + ['transporter', version]
            lists.append(row + drugbank_data)

cols = ['drugbank_id', 'target_id', 'target_name', 'target_organism',
        'target_action', 'target_known_action', 'gene_symbol',
        'hgnc_id', 'pmid', 'interaction_type', 'version', 'drug_name',
        'create_date', 'update_date', 'drug_type', 'is_cancer_drug', 'approval_status']
drug2gene_drugbank = pd.DataFrame(lists, columns=cols)

# %%
def decode_binary(value):
    if isinstance(value,bytes):
        return value.decode()
    else:
        return value

drug2gene_drugbank['target_action'] = drug2gene_drugbank['target_action'].apply(decode_binary)
drug2gene_drugbank['approval_status'] = drug2gene_drugbank['approval_status'].apply(decode_binary)

# %%
drug2gene_drugbank = drug2gene_drugbank.loc[drug2gene_drugbank.target_organism == 'Human']

# %%
drug2gene_drugbank["hgnc_id"] = drug2gene_drugbank["hgnc_id"].str.replace("HGNC:", "")

# %%
db_name = "DrugBank"
drug2gene_drugbank = drug2gene_drugbank.assign(source_name=db_name, download_date=datetime.date.today().strftime("%Y-%m-%d"))

# %%
drug_data_containers[db_name] = drug2gene_drugbank

# %%
drugbank_xrefs = pd.read_csv(DRUGBANK_XREF_FILE)
drugbank_xrefs = drugbank_xrefs[["DrugBank ID", "Name", "PubChem Compound ID", "PharmGKB ID", "TTD ID"]]
drugbank_xrefs["name"] = drugbank_xrefs["Name"].str.lower()

# %%
drugbank_synonyms = pd.DataFrame(drug_synonyms, columns=["DrugBank ID", "name"])
drugbank_synonyms = pd.concat([drugbank_xrefs[["DrugBank ID", "name"]], drugbank_synonyms])

# %%
drugbank_synonyms
# Out:
#       DrugBank ID                                               name
# 0         DB00001                                          lepirudin
# 1         DB00002                                          cetuximab
# 2         DB00003                                       dornase alfa
# 3         DB00004                                denileukin diftitox
# 4         DB00005                                         etanercept
# 5         DB00006                                        bivalirudin
# 6         DB00007                                         leuprolide
# 7         DB00008                              peginterferon alfa-2a
# 8         DB00009                                          alteplase
# 9         DB00010                                         sermorelin
# 10        DB00011                                 interferon alfa-n1
# 11        DB00012                                   darbepoetin alfa
# 12        DB00013                                          urokinase
# 13        DB00014                                          goserelin
# 14        DB00015                                          reteplase
# 15        DB00016                                     erythropoietin
# 16        DB00017                                  salmon calcitonin
# 17        DB00018                                 interferon alfa-n3
# 18        DB00019                                      pegfilgrastim
# 19        DB00020                                       sargramostim
# 20        DB00021                                           secretin
# 21        DB00022                              peginterferon alfa-2b
# 22        DB00023                                       asparaginase
# 23        DB00024                                   thyrotropin alfa
# 24        DB00025           antihemophilic factor, human recombinant
# 25        DB00026                                           anakinra
# 26        DB00027                                       gramicidin d
# 27        DB00028                              immune globulin human
# 28        DB00029                                       anistreplase
# 29        DB00030                                      insulin human
# ...           ...                                                ...
# 15831     DB13185                           b"cipionate d'oxabolone"
# 15832     DB13185                          b'cipionato de oxabolona'
# 15833     DB13185             b'oxabolone 17-cyclopentanepropionate'
# 15834     DB13185                             b'oxabolone cypionate'
# 15835     DB13185                              b'oxaboloni cipionas'
# 15836     DB13191                              b'creatine phosphate'
# 15837     DB13191                          b'creatine phosphic acid'
# 15838     DB13191                                      b'creatine-p'
# 15839     DB13191                                   b'fosfocreatine'
# 15840     DB13191                   b'n-(n-phosphonoamido)sarcosine'
# 15841     DB13191                   b'n-(phosphonoamidino)sarcosine'
# 15842     DB13191                               b'n-phosphocreatine'
# 15843     DB13191                            b'n-phosphorylcreatine'
# 15844     DB13191                              b'phosphorylcreatine'
# 15845     DB13192                b'antihemophilic factor viii human'
# 15846     DB13192                    b'antihemophilic factor, human'
# 15847     DB13192       b'antihemophilic factor, human (monoclonal)'
# 15848     DB13192                     b'antihemophilic factor,human'
# 15849     DB13192            b'factor viii (antihaemophilic factor)'
# 15850     DB13192                             b'factor viii (human)'
# 15851     DB13192                   b'human coagulation factor viii'
# 15852     DB13866  b'(3\xce\xb2,17\xce\xb1)-19-norpregn-4-en-20-y...
# 15853     DB13866  b'17\xce\xb1-ethynyl-19-norandrost-4-ene-3\xce...
# 15854     DB13866                 b'3\xce\xb2-hydroxynorethisterone'
# 15855     DB13866                                   b'aethynodiolum'
# 15856     DB13866                                      b'ethinodiol'
# 15857     DB13866                                       b'etinodiol'
# 15858     DB13866                                b'\xc3\xa9tynodiol'
# 15859     DB13866                                       b'etynodiol'
# 15860     DB13866                                     b'etynodiolum'
#
# [25449 rows x 2 columns]

# %%
drug2gene_drugbank.loc[drug2gene_drugbank.drug_name.isnull()]
# Out:
# Empty DataFrame
# Columns: [drugbank_id, target_id, target_name, target_organism, target_action, target_known_action, gene_symbol, hgnc_id, pmid, interaction_type, version, drug_name, create_date, update_date, drug_type, is_cancer_drug, approval_status, download_date, source_name]
# Index: []

# %% [markdown]
# ## TTD

# %%
TTD_TARGETS_DOWNLOAD = "http://database.idrb.cqu.edu.cn/TTD/download/TTD_download.txt"
TTD_DRUGS_XREFS_DOWNLOAD = "http://database.idrb.cqu.edu.cn/TTD/download/TTD_crossmatching.txt"
TTD_XREFS_DOWNLOAD = "http://bidd.nus.edu.sg/BIDD-Databases/TTD/download/TTD_uniprot_all.txt"
TTD_DRUGS_DOWNLOAD = "http://database.idrb.cqu.edu.cn/TTD/download/All.sdf"
TTD_SDF_FILE = os.path.join(data_path, "TTD_molecules.sdf")

# %% [markdown]
# Read TTD molecules

# %%
exit_code_ttd_sdf = 1
i = 0
while exit_code_ttd_sdf > 0 and i < 10:
    exit_code_ttd_sdf = subprocess.call("wget -O " + TTD_SDF_FILE + " " +  TTD_DRUGS_DOWNLOAD, shell=True)
    print(exit_code_ttd_sdf)
    i += 1
# Out:
# 0

# %%
ttd2cid = {}
ttd_smiles = {}
structures = Chem.SDMolSupplier(TTD_SDF_FILE)
for s in structures:
    if s is not None:
        db_id  = s.GetProp("_Name")
        db_cid = s.GetPropsAsDict().get("PUBCHEM_COMPOUND_CID")
        ttd_smiles[db_id] = Chem.MolToSmiles(s)
        if db_cid is not None:
            ttd2cid[db_id] = db_cid
ttd2smiles = pd.DataFrame(list(ttd_smiles.items()), columns=["ttd_drug_id", 'SMILES'])

# %%
ttd_drugs = pd.read_csv(TTD_DRUGS_XREFS_DOWNLOAD, skiprows=12, sep="\t",
                        names=["ttd_drug_id", "ign", "interaction_type", "drug_name"])
ttd_drugs = ttd_drugs.loc[ttd_drugs.interaction_type == 'DrugName'][["ttd_drug_id", "drug_name"]]
ttd2uniprot = pd.read_table(TTD_XREFS_DOWNLOAD, skiprows=12)\
                .rename(columns={"TTD Target ID": "target_id", "Uniprot ID": "uniprot_id"})

ttd_targets = pd.read_csv(TTD_TARGETS_DOWNLOAD, skiprows=12, sep="\t",
                          names=["target_id", "edge_type", "target"])\
    .rename(columns={'ttd_id': 'target_id'})\
    .drop_duplicates()

ttd2drug = ttd_targets.loc[ttd_targets.edge_type == "Drug(s)"]
ttd2drug.rename(columns={"target": "drug_name"}, inplace=True)
ttd2drug = ttd2drug.merge(ttd_drugs)
ttd2drug["drug_name"] = ttd2drug["drug_name"].str.lower()


ttd2drug_subtype = ttd_targets.loc[ttd_targets.edge_type.isin(["Inhibitor", "Agonist", "Antagonist", "Modulator", "Binder"])]
ttd2drug_subtype.rename(columns={"edge_type": "target_action", "target": "drug_name"}, inplace=True)
ttd2drug_subtype["drug_name"] = ttd2drug_subtype["drug_name"].str.lower()
# Out:
# /Users/Heisenberg/anaconda/envs/clinicalreporting/lib/python3.5/site-packages/pandas/core/frame.py:2834: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
# /Users/Heisenberg/anaconda/envs/clinicalreporting/lib/python3.5/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
drug2gene_ttd = ttd2drug.merge(ttd2drug_subtype, left_on=["target_id", "drug_name"], right_on=["target_id", "drug_name"], how="outer")\
        .merge(ttd2smiles, left_on="ttd_drug_id", right_on="ttd_drug_id")\
        .merge(drugbank_xrefs[["DrugBank ID", "TTD ID"]], left_on="ttd_drug_id", right_on="TTD ID", how="left")\
        .merge(drugbank_xrefs[["DrugBank ID", "Name"]], left_on="drug_name", right_on="Name", how="left")\
        .merge(drugbank2smiles, left_on="SMILES", right_on="SMILES", how="left")\
        .merge(ttd2uniprot, left_on="target_id", right_on="target_id")\
        .drop_duplicates()

# %%
drug2gene_ttd["drugbank_id"] = drug2gene_ttd.apply(combine_cols, args=(["DrugBank ID_x", "DrugBank ID_y", 'drugbank_id'],), axis=1)
drug2gene_ttd = drug2gene_ttd[['drugbank_id', "drug_name", "target_id", "uniprot_id", "target_action", "ttd_drug_id"]]
drug2gene_ttd = drug2gene_ttd.dropna(subset=['drugbank_id'])

# %%
uniprot_split = pd.DataFrame([(i, x.split(" (")[0].strip()) for i, row in drug2gene_ttd.iterrows()
                              for x in row['uniprot_id'].split(';')], columns=['df_index', 'uniprot_id'])
uniprot_split.set_index('df_index', inplace=True)
drug2gene_ttd = drug2gene_ttd.join(uniprot_split, lsuffix="s")\
                             .drop("uniprot_ids", axis=1)\
                             .merge(genes2uniprot, left_on="uniprot_id", right_on="uniprot_ids")\
                             .drop("uniprot_ids", axis=1)

# %%
drug2gene_ttd = drug2gene_ttd.merge(genes[["hgnc_id", "gene_symbol"]], left_on="hgnc_id", right_on="hgnc_id",
                                    suffixes=["", "_dup"])

# %%
db_name = "TTD"
db_pmid = "PMC4702870"
interaction_type = 'target'

drug2gene_ttd = drug2gene_ttd.assign(source_name=db_name, pmid=db_pmid,
                                     interaction_type=interaction_type,
                                     download_date=datetime.date.today().strftime("%Y-%m-%d"))

# %%
drug2gene_ttd.sort_values(by='drugbank_id')
# Out:
#      drugbank_id                 drug_name  target_id target_action  \
# 647      DB00001                 lepirudin  TTDS00202     Inhibitor
# 645      DB00006               bivalirudin  TTDS00202     Inhibitor
# 63       DB00010                sermorelin  TTDS00446        Binder
# 1912     DB00017         salmon calcitonin  TTDS00485        Binder
# 1825     DB00021                  secretin  TTDS00491        Binder
# 2166     DB00030       insulin recombinant  TTDS00292        Binder
# 1823     DB00035                     ddavp  TTDS00111       Agonist
# 813      DB00040      glucagon recombinant  TTDS00439        Binder
# 2169     DB00046            insulin lispro  TTDS00292        Binder
# 1919     DB00050                cetrorelix  TTDS00273    Antagonist
# 2125     DB00063              eptifibatide  TTDS00077    Antagonist
# 2127     DB00063              eptifibatide  TTDS00077    Antagonist
# 1822     DB00067               vasopressin  TTDS00111       Agonist
# 1452     DB00086             streptokinase  TTDS00392           NaN
# 1675     DB00091             cyclosporin a  TTDS00363     Inhibitor
# 1678     DB00091              cyclosporine  TTDS00363     Inhibitor
# 1683     DB00091              cyclosporine  TTDS00363     Inhibitor
# 1680     DB00091             cyclosporin a  TTDS00363     Inhibitor
# 1812     DB00093               felypressin  TTDS00109       Agonist
# 1977     DB00094            urofollitropin  TTDS00438        Binder
# 1869     DB00104                octreotide  TTDS00394        Binder
# 2236     DB00106                  abarelix  TTDS00253     Inhibitor
# 1727     DB00114       pyridoxal phosphate  TTDS00024     Inhibitor
# 1724     DB00119              pyruvic acid  TTDS00024     Inhibitor
# 2155     DB00120           l-phenylalanine  TTDS00365        Binder
# 2154     DB00120           l-phenylalanine  TTDS00365        Binder
# 1694     DB00126                 ascorbate  TTDR01222           NaN
# 1673     DB00131   adenosine monophosphate  TTDS00500        Binder
# 82       DB00133                  d-serine  TTDR00771     Inhibitor
# 742      DB00133                  d-serine  TTDR01259     Inhibitor
# ...          ...                       ...        ...           ...
# 973      DB13029                   mk-0873  TTDS00280     Inhibitor
# 531      DB13032                  enecadin  TTDS00402     Inhibitor
# 598      DB13036                ramatroban  TTDS00395    Antagonist
# 371      DB13040                 ly2784544  TTDC00187     Modulator
# 356      DB13044                  gossypol  TTDC00319           NaN
# 1518     DB13053                 cp-195543  TTDC00129    Antagonist
# 1895     DB13058  methanesulfonyl fluoride  TTDS00140     Inhibitor
# 329      DB13059               pf-03814735  TTDC00006     Inhibitor
# 322      DB13059               pf-03814735  TTDC00139     Inhibitor
# 334      DB13061                   mln8054  TTDC00006     Inhibitor
# 49       DB13063              parthenolide  TTDR01206     Inhibitor
# 47       DB13063              parthenolide  TTDC00046     Inhibitor
# 758      DB13066                 liarozole  TTDS00252     Inhibitor
# 2073     DB13066                 liarozole  TTDC00232     Inhibitor
# 838      DB13072                  gdc-0349  TTDS00265     Inhibitor
# 1554     DB13074               macimorelin  TTDC00127       Agonist
# 2074     DB13083                 rambazole  TTDC00232     Inhibitor
# 2075     DB13083                  r-115866  TTDC00232     Inhibitor
# 1078     DB13087                     cphpc  TTDC00180     Inhibitor
# 691      DB13094               pruvanserin  TTDS00105     Inhibitor
# 699      DB13094               pruvanserin  TTDS00103     Inhibitor
# 1784     DB13098                   ct-2584  TTDR00172     Modulator
# 1782     DB13098                   ct-2584  TTDR00172     Modulator
# 1414     DB13104                     x-396  TTDI02271     Inhibitor
# 2109     DB13106                  sc-49483  TTDS00291     Inhibitor
# 395      DB13113              jnj-38877605  TTDC00110     Inhibitor
# 2160     DB13118                paquinimod  TTDR00790     Inhibitor
# 931      DB13122                  ino-8875  TTDS00186       Agonist
# 1594     DB13132               artemisinin  TTDS00059     Inhibitor
# 1228     DB13139                salbutamol  TTDS00037       Agonist
#
#      ttd_drug_id uniprot_id  hgnc_id gene_symbol download_date  \
# 647    DAP000541     P00734     3535          F2    2017-08-03
# 645    DAP000542     P00734     3535          F2    2017-08-03
# 63     DAP001055     Q02643     4266       GHRHR    2017-08-03
# 1912   DAP001302     P30988     1440       CALCR    2017-08-03
# 1825   DAP001296     P47872    10608        SCTR    2017-08-03
# 2166   DAP000802     P06213     6091        INSR    2017-08-03
# 1823   DNC000526     P30518      897       AVPR2    2017-08-03
# 813    DAP001037     P47871     4192        GCGR    2017-08-03
# 2169   DNC000800     P06213     6091        INSR    2017-08-03
# 1919   DAP000096     P30968     4421       GNRHR    2017-08-03
# 2125   DAP000285     P05106     6156       ITGB3    2017-08-03
# 2127   DAP000285     P08514     6138      ITGA2B    2017-08-03
# 1822   DAP000018     P30518      897       AVPR2    2017-08-03
# 1452   DAP001198     P00747     9071         PLG    2017-08-03
# 1675   DCL000762     P63098     9317      PPP3R1    2017-08-03
# 1678   DAP000014     P63098     9317      PPP3R1    2017-08-03
# 1683   DAP000014     Q08209     9314      PPP3CA    2017-08-03
# 1680   DCL000762     Q08209     9314      PPP3CA    2017-08-03
# 1812   DAP000217     P37288      895      AVPR1A    2017-08-03
# 1977   DAP001029     P23945     3969        FSHR    2017-08-03
# 1869   DAP000397     P30874    11331       SSTR2    2017-08-03
# 2236   DAP000094     P01148     4419       GNRH1    2017-08-03
# 1727   DAP000804     P80404       23        ABAT    2017-08-03
# 1724   DAP000543     P80404       23        ABAT    2017-08-03
# 2155   DAP000807     P07101    11782          TH    2017-08-03
# 2154   DAP000807     P07101    11782          TH    2017-08-03
# 1694   DNC000259     Q02809     9081       PLOD1    2017-08-03
# 1673   DAP001319     Q08828      232       ADCY1    2017-08-03
# 82     DNC002629     P23415     4326       GLRA1    2017-08-03
# 742    DNC002629     Q05586     4584       GRIN1    2017-08-03
# ...          ...        ...      ...         ...           ...
# 973    DIB014984     P27815     8780       PDE4A    2017-08-03
# 531    DNC012245     Q14524    10593       SCN5A    2017-08-03
# 598    DCL000318     P21731    11608      TBXA2R    2017-08-03
# 371   DNCL003510     O60674     6192        JAK2    2017-08-03
# 356    DNC000701     P10415      990        BCL2    2017-08-03
# 1518   DIB012054     Q15722     6713       LTB4R    2017-08-03
# 1895   DIB003305     P22303      108        ACHE    2017-08-03
# 329    DCL001076     O14965    11393       AURKA    2017-08-03
# 322    DCL001076     Q96GD4    11390       AURKB    2017-08-03
# 334    DCL000169     O14965    11393       AURKA    2017-08-03
# 49     DNC001093     O14920     5960       IKBKB    2017-08-03
# 47     DNC001093     Q00653     7795       NFKB2    2017-08-03
# 758    DNC008925     P11511     2594     CYP19A1    2017-08-03
# 2073   DNC008925     O43174     2603     CYP26A1    2017-08-03
# 838   DNCL002333     P42345     3942        MTOR    2017-08-03
# 1554   DIB013193     Q92847     4267        GHSR    2017-08-03
# 2074   DCL000950     O43174     2603     CYP26A1    2017-08-03
# 2075   DNC008926     O43174     2603     CYP26A1    2017-08-03
# 1078   DIB015155     P05067      620         APP    2017-08-03
# 691    DNC011099     P28335     5295       HTR2C    2017-08-03
# 699    DNC011099     P28223     5293       HTR2A    2017-08-03
# 1784   DIB006887     Q9Y5K3     8755      PCYT1B    2017-08-03
# 1782   DIB006887     P49585     8754      PCYT1A    2017-08-03
# 1414   DIB014720     Q9UM73      427         ALK    2017-08-03
# 2109   DIB011930     O43451     7043        MGAM    2017-08-03
# 395    DIB004424     P08581     7029         MET    2017-08-03
# 2160   DIB001155     P06702    10499      S100A9    2017-08-03
# 931    DIB001403     P30542      262      ADORA1    2017-08-03
# 1594   DAP001454     Q02127     2867       DHODH    2017-08-03
# 1228   DAP000248     P07550      286       ADRB2    2017-08-03
#
#      interaction_type        pmid source_name
# 647            target  PMC4702870         TTD
# 645            target  PMC4702870         TTD
# 63             target  PMC4702870         TTD
# 1912           target  PMC4702870         TTD
# 1825           target  PMC4702870         TTD
# 2166           target  PMC4702870         TTD
# 1823           target  PMC4702870         TTD
# 813            target  PMC4702870         TTD
# 2169           target  PMC4702870         TTD
# 1919           target  PMC4702870         TTD
# 2125           target  PMC4702870         TTD
# 2127           target  PMC4702870         TTD
# 1822           target  PMC4702870         TTD
# 1452           target  PMC4702870         TTD
# 1675           target  PMC4702870         TTD
# 1678           target  PMC4702870         TTD
# 1683           target  PMC4702870         TTD
# 1680           target  PMC4702870         TTD
# 1812           target  PMC4702870         TTD
# 1977           target  PMC4702870         TTD
# 1869           target  PMC4702870         TTD
# 2236           target  PMC4702870         TTD
# 1727           target  PMC4702870         TTD
# 1724           target  PMC4702870         TTD
# 2155           target  PMC4702870         TTD
# 2154           target  PMC4702870         TTD
# 1694           target  PMC4702870         TTD
# 1673           target  PMC4702870         TTD
# 82             target  PMC4702870         TTD
# 742            target  PMC4702870         TTD
# ...               ...         ...         ...
# 973            target  PMC4702870         TTD
# 531            target  PMC4702870         TTD
# 598            target  PMC4702870         TTD
# 371            target  PMC4702870         TTD
# 356            target  PMC4702870         TTD
# 1518           target  PMC4702870         TTD
# 1895           target  PMC4702870         TTD
# 329            target  PMC4702870         TTD
# 322            target  PMC4702870         TTD
# 334            target  PMC4702870         TTD
# 49             target  PMC4702870         TTD
# 47             target  PMC4702870         TTD
# 758            target  PMC4702870         TTD
# 2073           target  PMC4702870         TTD
# 838            target  PMC4702870         TTD
# 1554           target  PMC4702870         TTD
# 2074           target  PMC4702870         TTD
# 2075           target  PMC4702870         TTD
# 1078           target  PMC4702870         TTD
# 691            target  PMC4702870         TTD
# 699            target  PMC4702870         TTD
# 1784           target  PMC4702870         TTD
# 1782           target  PMC4702870         TTD
# 1414           target  PMC4702870         TTD
# 2109           target  PMC4702870         TTD
# 395            target  PMC4702870         TTD
# 2160           target  PMC4702870         TTD
# 931            target  PMC4702870         TTD
# 1594           target  PMC4702870         TTD
# 1228           target  PMC4702870         TTD
#
# [2304 rows x 12 columns]

# %%
drug_data_containers[db_name] = drug2gene_ttd

# %% [markdown]
# ## IUPHAR

# %%
IUPHAR_INTERACTIONS_DOWNLOAD="http://www.guidetopharmacology.org/DATA/interactions.csv"
IUPHAR_HGNC_MAPPING_DOWNLOAD="http://www.guidetopharmacology.org/DATA/GtP_to_HGNC_mapping.csv"
IUPHAR_LIGANDS_DOWNLOAD="http://www.guidetopharmacology.org/DATA/ligands.csv"

# %%
iuphar_ligands = pd.read_csv(IUPHAR_LIGANDS_DOWNLOAD)
drug_ids = iuphar_ligands["Ligand id"].tolist()

xrefs_drugs = []
url_db_xlink_base = "http://www.guidetopharmacology.org/services/ligands/{}/databaseLinks"
missed = []
iuphar2drugbank = []
print(len(drug_ids), "ligands in IUPHAR.")

for i, x in enumerate(drug_ids):
    r = requests.get(url_db_xlink_base.format(x))
    if r.status_code == 200:
        if i % 500 == 0:
            print(i)
        drugbank_ids = [d["accession"] for d in r.json() if d['database'] == 'DrugBank Ligand']
        if len(drugbank_ids) > 0:
            for d in drugbank_ids:
                iuphar2drugbank.append([x, d])
        else:
            missed.append(x)

iuphar2drugbank = pd.DataFrame(iuphar2drugbank, columns=["iuphar_id", "drugbank_id"])
print(len(set(missed)), " ligands without drugbank id.")
# Out:
# 8900 ligands in IUPHAR.
# 0
# 1000
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 8000
# 8500
# 6667  ligands without drugbank id.

# %%
iuphar2drugbank.to_csv(data_path + "\iuphar2drugbank.csv", sep="\t")

# %%
iuphar2hgnc = pd.read_csv(IUPHAR_HGNC_MAPPING_DOWNLOAD)

# %%
iuphar_interactions = pd.read_csv(IUPHAR_INTERACTIONS_DOWNLOAD)\
                        .rename(columns={'type': 'target_action',
                                         'action': 'target_action_detailed',
                                         'pubmed_id': 'pmid',
                                         'target': 'target_name',
                                         'target_species': 'target_organism',
                                         'target_gene_symbol': 'gene_symbol',
                                         'target_uniprot': 'uniprot_id',
                                         'ligand': 'drug_name',
                                         'target_id': 'iuphar_id'})
# Out:
# /Users/Heisenberg/anaconda/envs/clinicalreporting/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (4,6,7,20,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
drug2gene_iuphar = iuphar_interactions.merge(iuphar2hgnc[['iuphar_id', 'hgnc_id']],
                                             left_on="iuphar_id", right_on="iuphar_id")\
                                      .merge(iuphar2drugbank,
                                             left_on="ligand_id", right_on="iuphar_id")

# %%
drug2gene_iuphar = drug2gene_iuphar.loc[drug2gene_iuphar.target_organism == 'Human']

# %%
drug2gene_iuphar = drug2gene_iuphar[[x for x in drug2gene_iuphar.columns
                                     if not x.startswith("target_ligand") and not x.endswith("_x")
                                     and not x.endswith("_y") and not "original" in x
                                     and not x in ['ligand_gene_symbol', 'ligand_species', 'ligand_pubchem_sid']]]

# %%
db_name = "IUPHAR"
interaction_type = 'target'
drug2gene_iuphar = drug2gene_iuphar.assign(source_name=db_name, interaction_type=interaction_type,
                                           download_date=datetime.date.today().strftime("%Y-%m-%d"))

# %%
drug_data_containers[db_name] = drug2gene_iuphar

# %% [markdown]
# ## Santos dataset
# this is the supplement from the following paper. A frequently maintained version should be available on Pharos, but downloading the relevant data would require downloading and extracting the database dump first.

# %%
SANTOS_SUPPLEMENT_DOWNLOAD="http://www.nature.com/nrd/journal/v16/n1/extref/nrd.2016.230-s2.xlsx"

# %%
rename_cols = {"ACCESSION": "uniprot_id",
               "ORGANISM": "target_species",
               "PROTEIN_NAME": "target_name",
               "PARENT_PREF_NAME": "drug_name",
#                                       "PARENT_PREF_NAME": "drug_name",
               "MECHANISM_OF_ACTION": "action_comment"}
drug2gene_santos = pd.read_excel(SANTOS_SUPPLEMENT_DOWNLOAD)\
                     .rename(columns=rename_cols)

# %%
drug2gene_santos = drug2gene_santos.loc[drug2gene_santos["target_species"] == "Homo sapiens"]
drug2gene_santos = drug2gene_santos.dropna(subset=["uniprot_id"])
drug2gene_santos["drug_name"] = drug2gene_santos["drug_name"].str.lower()

# %%
drug2gene_santos = drug2gene_santos.merge(drugbank_synonyms, left_on="drug_name", right_on="name")\
                                   .rename(columns={"DrugBank ID": "drugbank_id"})

# %%
list(rename_cols.values())
# Out:
# ['action_comment', 'drug_name', 'target_species', 'target_name', 'uniprot_id']

# %%
drug2gene_santos = drug2gene_santos[list(rename_cols.values()) + ["drugbank_id"]]\
    .merge(genes2uniprot, left_on="uniprot_id", right_on="uniprot_ids")\
    .drop("uniprot_ids", axis=1)\
    .merge(genes[["hgnc_id", "gene_symbol"]], left_on="hgnc_id", right_on="hgnc_id",
                  suffixes=["", "_dup"])

# %%
db_name = "Santos"
pmid = "27910877"
interaction_type = 'target'
drug2gene_santos = drug2gene_santos.assign(source_name=db_name, pmid=pmid,
                                           download_date=datetime.date.today().strftime("%Y-%m-%d"),
                                           interaction_type=interaction_type)

# %%
drug_data_containers[db_name] = drug2gene_santos

# %% [markdown]
# # Let's wrap it up

# %%
include_cols = [u'hgnc_id', u'gene_symbol', u'drugbank_id', u'drug_name',
                u'target_action', 'target_id', u'interaction_type',
                #u'target_action_detailed',
                #u'primary_target', 
                u'target_known_action',
                u'pmid', u'source_name', u'download_date' ]
drug_df_final = reduce(lambda left,right: pd.concat([left,right], ignore_index=True,
                                                    join='outer'), drug_data_containers.values())[include_cols]
drug_df_final = drug_df_final.replace('', np.nan)

# %%
drug_df_final = drug_df_final.merge(pd.DataFrame(list(drug_atc.items()), columns=["drugbank_id", "ATC_code"]))\
                             .merge(drug_data_containers["DrugBank"][["drugbank_id", "approval_status"]], how="outer")\
                             .merge(pd.DataFrame(list(cancer_drugs.items()), columns=["drugbank_id", "is_cancer_drug"]))\
                             .drop_duplicates()

# %%
drug_df_final = drug_df_final[drug_df_final['hgnc_id'].notnull()]#.loc[drug_df_final['hgnc_id']=='null']

# %%
drug_df_final.fillna('null',inplace=True)

# %%
drug_df_final['hgnc_id'] = drug_df_final['hgnc_id'].astype(int).astype(str)

# %%
drug_df_final
# Out:
#        hgnc_id gene_symbol drugbank_id                         drug_name  \
# 0           23        ABAT     DB01080                        vigabatrin
# 3        11018     SLC32A1     DB01080                        vigabatrin
# 6           23        ABAT     DB01080                        vigabatrin
# 9           23        ABAT     DB01080                        vigabatrin
# 12        4070      GABBR1     DB01080                        vigabatrin
# 15          23        ABAT     DB01080                        vigabatrin
# 18       18761     SLC36A1     DB01080                        vigabatrin
# 21        5286       HTR1A     DB04908                       flibanserin
# 25        5293       HTR2A     DB04908                       flibanserin
# 29        5293       HTR2A     DB04908                       flibanserin
# 33        5286       HTR1A     DB04908                       flibanserin
# 37        5286       HTR1A     DB04908                       flibanserin
# 41        5293       HTR2A     DB04908                       flibanserin
# 45        3025        DRD4     DB04908                       flibanserin
# 49        2637      CYP3A4     DB04908                       flibanserin
# 53        5286       HTR1A     DB00998                      frovatriptan
# 56        5287       HTR1B     DB00998                      frovatriptan
# 59        5289       HTR1D     DB00998                      frovatriptan
# 62        5287       HTR1B     DB00998                      frovatriptan
# 65        5289       HTR1D     DB00998                      frovatriptan
# 68        5289       HTR1D     DB00998                      frovatriptan
# 71        5287       HTR1B     DB00998                      frovatriptan
# 74        5289       HTR1D     DB00998                      frovatriptan
# 77        5287       HTR1B     DB00998                      frovatriptan
# 80        2596      CYP1A2     DB00998                      frovatriptan
# 83        5286       HTR1A     DB00248                       cabergoline
# 107       5287       HTR1B     DB00248                       cabergoline
# 131       5289       HTR1D     DB00248                       cabergoline
# 155       5293       HTR2A     DB00248                       cabergoline
# 179       5294       HTR2B     DB00248                       cabergoline
# ...        ...         ...         ...                               ...
# 214671    5286       HTR1A     DB13025                          tiapride
# 214677     277      ADRA1A     DB13025                          tiapride
# 214683     281      ADRA2A     DB13025                          tiapride
# 214689    5182        HRH1     DB13025                          tiapride
# 214695    2439       CSF3R     DB13144                       lenograstim
# 214696    3528         F10     DB13151  anti-inhibitor coagulant complex
# 214709    3535          F2     DB13151  anti-inhibitor coagulant complex
# 214722    3661         FGA     DB13151  anti-inhibitor coagulant complex
# 214735    3662         FGB     DB13151  anti-inhibitor coagulant complex
# 214748    3531       F13A1     DB13151  anti-inhibitor coagulant complex
# 214761    3542          F5     DB13151  anti-inhibitor coagulant complex
# 214774    3546          F8     DB13151  anti-inhibitor coagulant complex
# 214787    3544          F7     DB13151  anti-inhibitor coagulant complex
# 214800    3535          F2     DB13151  anti-inhibitor coagulant complex
# 214813    3544          F7     DB13151  anti-inhibitor coagulant complex
# 214826    3546          F8     DB13151  anti-inhibitor coagulant complex
# 214839    3551          F9     DB13151  anti-inhibitor coagulant complex
# 214852    3542          F5     DB13151  anti-inhibitor coagulant complex
# 214865    7978       NR3C1     DB13158                       clobetasone
# 214866    2707         ACE     DB13166                        zofenopril
# 214867    9605       PTGS2     DB13167                        alclofenac
# 214868    2621     CYP2C19     DB13179                    troleandomycin
# 214877    2638      CYP3A5     DB13179                    troleandomycin
# 214886    2623      CYP2C9     DB13179                    troleandomycin
# 214895   17450     CYP3A43     DB13179                    troleandomycin
# 214904    2610      CYP2A6     DB13179                    troleandomycin
# 214913    2620     CYP2C18     DB13179                    troleandomycin
# 214922    2622      CYP2C8     DB13179                    troleandomycin
# 214931    2637      CYP3A4     DB13179                    troleandomycin
# 214940      40       ABCB1     DB13179                    troleandomycin
#
#               target_action  target_id interaction_type target_known_action  \
# 0                 Inhibitor       null           target                null
# 3                 Inhibitor       null           target                null
# 6                 Inhibitor  TTDS00024           target                null
# 9                      null       null           target                null
# 12                  agonist  BE0000217           target                 yes
# 15                inhibitor  BE0000253           target                 yes
# 18                     null  BE0000536      transporter             unknown
# 21                  Agonist       null           target                null
# 25               Antagonist       null           target                null
# 29                  Agonist  TTDS00103           target                null
# 33                  Agonist  TTDS00098           target                null
# 37                  agonist  BE0000291           target                 yes
# 41               antagonist  BE0000451           target                 yes
# 45               antagonist  BE0000389           target                 yes
# 49                substrate  BE0002638           enzyme                  no
# 53                  Agonist       null           target                null
# 56                  Agonist       null           target                null
# 59                  Agonist       null           target                null
# 62                  Agonist  TTDS00099           target                null
# 65                  Agonist  TTDS00100           target                null
# 68                     null       null           target                null
# 71                     null       null           target                null
# 74                  agonist  BE0000659           target                 yes
# 77                  agonist  BE0000797           target                 yes
# 80                substrate  BE0002433           enzyme             unknown
# 83                  Agonist       null           target                null
# 107                 Agonist       null           target                null
# 131                 Agonist       null           target                null
# 155                 Agonist       null           target                null
# 179                 Agonist       null           target                null
# ...                     ...        ...              ...                 ...
# 214671           antagonist  BE0004862           target                 yes
# 214677           antagonist  BE0004863           target                 yes
# 214683           antagonist  BE0004864           target                 yes
# 214689           antagonist  BE0000442           target                 yes
# 214695              agonist  BE0000793           target                 yes
# 214696              agonist  BE0000216           target                 yes
# 214709              agonist  BE0000048           target                 yes
# 214722             cleavage  BE0000538           target                 yes
# 214735             cleavage  BE0002091           target                 yes
# 214748              agonist  BE0000004           target                 yes
# 214761              agonist  BE0000041           target                 yes
# 214774              agonist  BE0000016           target                 yes
# 214787              agonist  BE0000333           target                 yes
# 214800            substrate  BE0000048           enzyme                 yes
# 214813            substrate  BE0000333           enzyme                 yes
# 214826            substrate  BE0000016           enzyme                 yes
# 214839            substrate  BE0000364           enzyme                 yes
# 214852            substrate  BE0000041           enzyme                 yes
# 214865              agonist  BE0000794           target                 yes
# 214866            inhibitor  BE0000221           target                 yes
# 214867           antagonist  BE0000262           target                 yes
# 214868            inhibitor  BE0003536           enzyme             unknown
# 214877                 null  BE0002362           enzyme             unknown
# 214886                 null  BE0002793           enzyme             unknown
# 214895              inducer  BE0003550           enzyme             unknown
# 214904            inhibitor  BE0003336           enzyme             unknown
# 214913            inhibitor  BE0003611           enzyme             unknown
# 214922            inhibitor  BE0002887           enzyme             unknown
# 214931  substrate|inhibitor  BE0002638           enzyme             unknown
# 214940            inhibitor  BE0001032      transporter             unknown
#
#                                                      pmid source_name  \
# 0                                         856582|22168767      IUPHAR
# 3                                                 9349821      IUPHAR
# 6                                              PMC4702870         TTD
# 9                                                27910877      Santos
# 12                                               20655489    DrugBank
# 15      10195585|10206175|10214744|10503933|10530689|1...    DrugBank
# 18                                               16331283    DrugBank
# 21                                               12177684      IUPHAR
# 25                                               12177684      IUPHAR
# 29                                             PMC4702870         TTD
# 33                                             PMC4702870         TTD
# 37                             12890707|12177684|26412054    DrugBank
# 41                             12177684|12890707|26412054    DrugBank
# 45                             12177684|12890707|26412054    DrugBank
# 49                                               26412054    DrugBank
# 53                                                9986723      IUPHAR
# 56                                                9986723      IUPHAR
# 59                                                9986723      IUPHAR
# 62                                             PMC4702870         TTD
# 65                                             PMC4702870         TTD
# 68                                               27910877      Santos
# 71                                               27910877      Santos
# 74      11752352|11735616|12028320|11152011|10883409|1...    DrugBank
# 77      11752352|15311727|12028320|9700983|11735616|17...    DrugBank
# 80                    11735616|12028321|12028322|19934256    DrugBank
# 83                                               12388666      IUPHAR
# 107                                              12388666      IUPHAR
# 131                                              12388666      IUPHAR
# 155                                              12388666      IUPHAR
# 179                                              12388666      IUPHAR
# ...                                                   ...         ...
# 214671                                           11520476    DrugBank
# 214677                                           11520476    DrugBank
# 214683                                           11520476    DrugBank
# 214689                                           11520476    DrugBank
# 214695                                               null    DrugBank
# 214696                                           15385040    DrugBank
# 214709                                           15385040    DrugBank
# 214722                                           15385040    DrugBank
# 214735                                           15385040    DrugBank
# 214748                                           15385040    DrugBank
# 214761                                           15385040    DrugBank
# 214774                                           15385040    DrugBank
# 214787                                           15385040    DrugBank
# 214800                                           15385040    DrugBank
# 214813                                           15385040    DrugBank
# 214826                                           15385040    DrugBank
# 214839                                           15385040    DrugBank
# 214852                                           15385040    DrugBank
# 214865                                               null    DrugBank
# 214866                                           17355163    DrugBank
# 214867                                             241595    DrugBank
# 214868                                           19934256    DrugBank
# 214877                                           15557344    DrugBank
# 214886                                            8819299    DrugBank
# 214895                                           11095572    DrugBank
# 214904                                           19934256    DrugBank
# 214913                                           19934256    DrugBank
# 214922                                           19934256    DrugBank
# 214931                                           19934256    DrugBank
# 214940                         11716514|11961113|12235267    DrugBank
#
#        download_date                 ATC_code           approval_status  \
# 0         2017-08-03                  N03AG04                  approved
# 3         2017-08-03                  N03AG04                  approved
# 6         2017-08-03                  N03AG04                  approved
# 9         2017-08-03                  N03AG04                  approved
# 12        2017-08-04                  N03AG04                  approved
# 15        2017-08-04                  N03AG04                  approved
# 18        2017-08-04                  N03AG04                  approved
# 21        2017-08-03                  G02CX02                  approved
# 25        2017-08-03                  G02CX02                  approved
# 29        2017-08-03                  G02CX02                  approved
# 33        2017-08-03                  G02CX02                  approved
# 37        2017-08-04                  G02CX02                  approved
# 41        2017-08-04                  G02CX02                  approved
# 45        2017-08-04                  G02CX02                  approved
# 49        2017-08-04                  G02CX02                  approved
# 53        2017-08-03                  N02CC07  approved|investigational
# 56        2017-08-03                  N02CC07  approved|investigational
# 59        2017-08-03                  N02CC07  approved|investigational
# 62        2017-08-03                  N02CC07  approved|investigational
# 65        2017-08-03                  N02CC07  approved|investigational
# 68        2017-08-03                  N02CC07  approved|investigational
# 71        2017-08-03                  N02CC07  approved|investigational
# 74        2017-08-04                  N02CC07  approved|investigational
# 77        2017-08-04                  N02CC07  approved|investigational
# 80        2017-08-04                  N02CC07  approved|investigational
# 83        2017-08-03          N04BC06|G02CB03                  approved
# 107       2017-08-03          N04BC06|G02CB03                  approved
# 131       2017-08-03          N04BC06|G02CB03                  approved
# 155       2017-08-03          N04BC06|G02CB03                  approved
# 179       2017-08-03          N04BC06|G02CB03                  approved
# ...              ...                      ...                       ...
# 214671    2017-08-04                  N05AL03  approved|investigational
# 214677    2017-08-04                  N05AL03  approved|investigational
# 214683    2017-08-04                  N05AL03  approved|investigational
# 214689    2017-08-04                  N05AL03  approved|investigational
# 214695    2017-08-04                  L03AA10                  approved
# 214696    2017-08-04                  B02BD03                  approved
# 214709    2017-08-04                  B02BD03                  approved
# 214722    2017-08-04                  B02BD03                  approved
# 214735    2017-08-04                  B02BD03                  approved
# 214748    2017-08-04                  B02BD03                  approved
# 214761    2017-08-04                  B02BD03                  approved
# 214774    2017-08-04                  B02BD03                  approved
# 214787    2017-08-04                  B02BD03                  approved
# 214800    2017-08-04                  B02BD03                  approved
# 214813    2017-08-04                  B02BD03                  approved
# 214826    2017-08-04                  B02BD03                  approved
# 214839    2017-08-04                  B02BD03                  approved
# 214852    2017-08-04                  B02BD03                  approved
# 214865    2017-08-04  S01BA09|S01CA11|D07AB01                  approved
# 214866    2017-08-04          C09BA15|C09AA15              experimental
# 214867    2017-08-04                  M01AB06        approved|withdrawn
# 214868    2017-08-04                  J01FA08                  approved
# 214877    2017-08-04                  J01FA08                  approved
# 214886    2017-08-04                  J01FA08                  approved
# 214895    2017-08-04                  J01FA08                  approved
# 214904    2017-08-04                  J01FA08                  approved
# 214913    2017-08-04                  J01FA08                  approved
# 214922    2017-08-04                  J01FA08                  approved
# 214931    2017-08-04                  J01FA08                  approved
# 214940    2017-08-04                  J01FA08                  approved
#
#        is_cancer_drug
# 0               False
# 3               False
# 6               False
# 9               False
# 12              False
# 15              False
# 18              False
# 21              False
# 25              False
# 29              False
# 33              False
# 37              False
# 41              False
# 45              False
# 49              False
# 53              False
# 56              False
# 59              False
# 62              False
# 65              False
# 68              False
# 71              False
# 74              False
# 77              False
# 80              False
# 83              False
# 107             False
# 131             False
# 155             False
# 179             False
# ...               ...
# 214671          False
# 214677          False
# 214683          False
# 214689          False
# 214695          False
# 214696          False
# 214709          False
# 214722          False
# 214735          False
# 214748          False
# 214761          False
# 214774          False
# 214787          False
# 214800          False
# 214813          False
# 214826          False
# 214839          False
# 214852          False
# 214865          False
# 214866          False
# 214867          False
# 214868          False
# 214877          False
# 214886          False
# 214895          False
# 214904          False
# 214913          False
# 214922          False
# 214931          False
# 214940          False
#
# [16661 rows x 14 columns]

# %%
# drug_df_final['drug_name'] = drug_df_final['drug_name'].to_string()

# %%
group_cols = ["hgnc_id"]
exclude_cols = group_cols + ["gene_symbol"]
groups = drug_df_final.groupby(group_cols)
for n, g in groups:
    all_genes[n]['drugs'] = g[[c for c in g.columns if c not in exclude_cols]].to_dict('records')
    all_genes[n]['drug_evidence_score'] = g.groupby(['drug_name'])\
        .agg({'source_name': lambda x: len(x)})\
        .reset_index()\
        .rename(columns={'source_name': 'drug_score'})\
        .to_dict('records')

# %% [markdown]
# # Dump json to file - for fun

# %%
import json

# %%
all_genes_json = json.dumps(all_genes, indent=4, sort_keys=True)

# %%
# %pwd
# Out:
# '/Users/Heisenberg/DockerStation/clinicalReporting_DB_RESTAPI/data'

# %%
with open("/Users/Heisenberg/DockerStation/clinicalReporting_DB_RESTAPI/data/driver_db_dump_v2.json", 'w') as f:
    f.write(all_genes_json)

# %% [markdown]
# # MongoDB stuff
#
# Install MongoDB: https://docs.mongodb.com/getting-started/shell/tutorial/install-mongodb-on-os-x/
# You could just save everyting to a .json and import it at the command line: https://docs.mongodb.com/getting-started/shell/import-data/
#
# Or,Use pymongo to place the documents into the database one by one. here is a link to a helpful tutorial: http://api.mongodb.com/python/current/tutorial.html
#
# You can use ```conda install pymongo```
#
# Although the already mentioned tutorial seems quicker, for completeness: https://docs.mongodb.com/getting-started/python/introduction/
#
# ### MongoDB Compass
# It's a seperate install. Intall after you have mongoDB installed. You'll need a running instance of your db up and running. You can do this by calling ```mongod``` on the command line. Then open up Compass and you'll see all the databases that you currently have running. After running the code below, you won't see the changes immediatly in a running Compass session, you'll have to press the sync button somewhere on the top left hand side of the interface.

# %%
# need pymongo
#import pymongo
#from pymongo import MongoClient

# %%
#client = MongoClient()
# you can call the database what you want; I chose "drivers"
#db = client['drivers']
# the collection will be called posts; change accordingly
#posts = db.cancer_genes

# %% [markdown]
# # alright pop it into the database

# %%
#posts.insert_many(all_genes.values())

# %%
# for i in range(len(df_scored)):
#     posts.insert_one(df_scored.iloc[i].to_dict())

# %% [markdown]
# # Check that it happened with example query

# %%
#for post in posts.find({"gene_symbol": "BRAF"}):
#    print(post)

# %%
#post["cancer"]

# %%
#found_targets = []
#for post in posts.find({"drugs":  {"$elemMatch": {"drugbank_id": "DB00002"}}}):
    #found_targets.append((post["gene_symbol"])
    #print(post)

# %%
#post["gene_symbol"]

# %%
#found_targets

# %%
#len(post["drugs"]), post["drugs"]
