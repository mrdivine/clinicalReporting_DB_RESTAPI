# %% [markdown]
# # Import Driver gene tables

# %% [markdown]
# collect the various driver genes from the various sources, placing them into
# the predifined json-schema outlined in "driversValidationSchemaLight.json". Start
# at the top of the list in the README, and just collect...
#
# When collecting, try to stay with a particular column naming
#
# "gene_symbol","driver_type","pmid","source_name"

# %%
import pandas as pd

# %%
columns_to_db = ["hgnc_id", "gene_symbol", "driver_type", "pmid", "source_name"]
source_container = {}
data_path = "../../clinicalreporting/drivers/Data/"

# %%
"""
HGNC Genes
"""
HGNC_DOWNLOAD = "ftp://ftp.ebi.ac.uk/pub/databases/genenames/new/tsv/hgnc_complete_set.txt"
UNIPROT_DOWNLOAD = "http://www.uniprot.org/uniprot/?query=reviewed:yes+AND+organism:9606&format=tab&compress=yes&columns=id,entry%20name,reviewed,protein%20names,genes,organism,length,sequence,ec,feature(ACTIVE%20SITE),feature(BINDING%20SITE),comment(TISSUE%20SPECIFICITY),go(biological%20process),go(molecular%20function),go(cellular%20component),go-id,comment(BIOTECHNOLOGY),comment(DISEASE),comment(PHARMACEUTICAL),feature(MUTAGENESIS),comment(DISRUPTION%20PHENOTYPE),last-modified,created,database(CCDS),database(EMBL),database(RefSeq),database(HGNC)"
genes = pd.read_csv(HGNC_DOWNLOAD, sep="\t").rename(columns={'symbol': 'gene_symbol'})
genes["hgnc_id"] = pd.to_numeric(genes["hgnc_id"].str.replace("HGNC:", ""))
gene_synonyms = [(s["hgnc_id"], x)
                 for i, s in genes[["hgnc_id", "alias_symbol"]].dropna(subset=["alias_symbol"]).iterrows()
                 for x in s["alias_symbol"].split("|") if x not in genes["gene_symbol"].tolist()]
gene_synonyms += [(s["hgnc_id"], x)
                  for i, s in genes[["hgnc_id", "prev_symbol"]].dropna(subset=["prev_symbol"]).iterrows()
                  for x in s["prev_symbol"].split("|") if x not in genes["gene_symbol"].tolist()]
gene_synonym_df = pd.concat([genes[["hgnc_id", "gene_symbol"]],
                             pd.DataFrame(gene_synonyms, columns=["hgnc_id", "gene_symbol"])])

# %%
genes = genes.assign(species='hsa', node_type='gene')
all_genes = genes[['hgnc_id', 'gene_symbol', 'name', 'status', 'locus_group', 'locus_type',
                   'gene_family', 'alias_symbol', 'prev_symbol', 'location', 'uniprot_ids',
                   'entrez_id', 'ensembl_gene_id', 'date_approved_reserved', 'date_modified',
                   'date_symbol_changed', 'species', 'node_type']].set_index('hgnc_id', drop=False).to_dict('index')
genes2entrez = genes[["hgnc_id", "entrez_id"]].dropna()
genes2uniprot = genes[["hgnc_id", "uniprot_ids"]].dropna()

# %%
"""
Vogelstein et al.
"""
path_name = data_path + 'Vogelstein_CancerGenomeLandscape_Science_2013.csv'
vogelstein_df = pd.read_csv(path_name,delimiter=';')
vogelstein_pmid = '23539594'
vogelstein_name = "Vogelstein"
vogelstein_df = vogelstein_df.assign(pmid=vogelstein_pmid,source_name=vogelstein_name)
# correct names for later mergin'
vogelstein_df = vogelstein_df.rename(index=str,columns={"Gene Symbol":"gene_symbol","Classification*":"driver_type"})
vogelstein_df = vogelstein_df.merge(gene_synonym_df)
vogelstein_df = vogelstein_df[columns_to_db+["Process","Core pathway"]]


source_container[vogelstein_name]=vogelstein_df


"""
Rubio-Perez
"""

path_name = data_path + 'Drivers_type_role.tsv'
rubiop_df = pd.read_csv(path_name,delimiter='\t',comment='#')
rubiop_pmid = "25759023"
rubiop_name = "Rubio-Perez"
rubiop_df = rubiop_df.assign(pmid=rubiop_pmid,source_name=rubiop_name)
rubiop_df = rubiop_df.rename(index=str,columns={"geneHGNCsymbol":"gene_symbol","Driver_type":"driver_type"})
rubiop_df = rubiop_df.merge(gene_synonym_df)

mapper = dict(zip(rubiop_df['Role'].unique(),["Oncogene","TSG","Unknown","Oncogene"]))
rubiop_df["driver_type"] = rubiop_df["Role"].map(mapper)
# rubiop_df.loc[rubiop_df['Role']=='A']

rubiop_df = rubiop_df[columns_to_db+["OncodriveROLE_prob"]]
source_container[rubiop_name] = rubiop_df

"""
Uniprot
"""

oncogene_path_name = data_path + '/uniprot-keyword%3A%22Proto-oncogene+%5BKW-0656%5D%22.tab'
tsg_path_name = data_path + '/uniprot-keyword%3A%22Tumor+suppressor+%5BKW-0043%5D%22.tab'

uniprot_oncogene_df = pd.read_csv(oncogene_path_name,'\t')
uniprot_oncogene_df["driver_type"] = "Oncogene"
uniprot_tsg_df = pd.read_csv(tsg_path_name,'\t')
uniprot_tsg_df["driver_type"] = "TSG"

uniprot_df = pd.concat([uniprot_tsg_df,uniprot_oncogene_df],axis=0)
uniprot_df["gene_symbol"] = uniprot_df["Gene names"].apply(lambda x: x.split(" ")[0])
uniprot_df = uniprot_df.merge(genes2uniprot, left_on="Entry", right_on="uniprot_ids").drop("uniprot_ids", axis=1)
uniprot_name = "Uniprot"
uniprot_pmid = "14681372"
uniprot_df = uniprot_df.assign(pmid=uniprot_pmid,source_name=uniprot_name)
uniprot_df = uniprot_df[columns_to_db]

source_container[uniprot_name] = uniprot_df


"""
Cosmic Census

"""

path_name = data_path + 'Census_allTue Mar 14 14_33_17 2017.tsv'
cosmic_df = pd.read_csv(path_name,"\t")
cosmic_name = "Cosmic"
cosmic_pmid = "14993899"
cosmic_df = cosmic_df.assign(source_name=cosmic_name,pmid=cosmic_pmid)

# cosmic_df["Role in Cancer"].unique()
mapper = dict(zip(cosmic_df["Role in Cancer"].unique(),["TSG","Oncogene","Unknown","Oncogene/TSG"]))

cosmic_df["driver_type"] = cosmic_df["Role in Cancer"].map(mapper)
cosmic_df = cosmic_df.rename(index=str, columns={"Gene Symbol":"gene_symbol"})
cosmic_df = cosmic_df.merge(genes2entrez, left_on="Entrez GeneId", right_on="entrez_id").drop("entrez_id", axis=1)
cosmic_df = cosmic_df[columns_to_db]

source_container[cosmic_name] = cosmic_df

"""
TSgene

"""
tsgene_pathname = data_path + 'Human_TSGs.txt'
tsgene_df = pd.read_csv(tsgene_pathname,delimiter="\t")
# tsgene_df[:1]

tsgene_name = "TSgene"
tsgene_pmid = "23066107"

tsgene_df= tsgene_df.assign(source_name=tsgene_name,pmid=tsgene_pmid,driver_type="TSG")
tsgene_df = tsgene_df.rename(index=str,columns={"GeneSymbol":"gene_symbol"})
tsgene_df = tsgene_df.merge(genes2entrez, left_on="GeneID", right_on="entrez_id").drop("entrez_id", axis=1)
tsgene_df = tsgene_df[columns_to_db]

source_container[tsgene_name] = tsgene_df

"""
putting it all together
"""
df_final = reduce(lambda left,right: pd.concat([left,right],ignore_index=True), source_container.values())
df_final.drop_duplicates(inplace=True)
# this seems a little too hacked for my tast. Don't know, feel free to change it and let me know what you did
df_scored = pd.merge(df_final,df_final.groupby("gene_symbol").count()["pmid"].to_frame(),left_on="gene_symbol",right_index=True)
df_scored = df_scored.rename(index=str,columns=dict(zip(["pmid_x","pmid_y"],["pmid","score"])))

# %%
# do a little speed-validating
print df_scored["score"].unique()
print df_scored["driver_type"].unique()
print df_final["gene_symbol"].unique()
# Out:
# [1 4 2 3 5]
# ['TSG' 'Oncogene' 'Unknown' 'Oncogene/TSG']
# ['ABI1' 'ABL1' 'ABL2' ..., 'ZNF638' 'ZNF750' 'ZNF814']

# %% [markdown]
# # Take a look at the finished table

# %%
df_scored[:100]
# Out:
#                 Core pathway OncodriveROLE_prob             Process  \
# 0                        NaN                NaN                 NaN
# 1                        NaN                NaN                 NaN
# 614     Cell Cycle/Apoptosis                NaN       Cell Survival
# 2136                     NaN                NaN                 NaN
# 2361                     NaN                NaN                 NaN
# 2                        NaN                NaN                 NaN
# 2362                     NaN              0.811                 NaN
# 3                        NaN                NaN                 NaN
# 4                        NaN                NaN                 NaN
# 2366                     NaN                NaN                 NaN
# 5                        NaN                NaN                 NaN
# 2367                     NaN             0.0455                 NaN
# 6                        NaN                NaN                 NaN
# 7                        NaN                NaN                 NaN
# 2372                     NaN              0.012                 NaN
# 8                        NaN                NaN                 NaN
# 2143                     NaN                NaN                 NaN
# 9                        NaN                NaN                 NaN
# 10                       NaN                NaN                 NaN
# 2144                     NaN                NaN                 NaN
# 2375                     NaN              0.682                 NaN
# 11                       NaN                NaN                 NaN
# 2379                     NaN             0.4245                 NaN
# 12                       NaN                NaN                 NaN
# 616                     PI3K                NaN       Cell Survival
# 2141                     NaN                NaN                 NaN
# 2380                     NaN             0.9945                 NaN
# 13                       NaN                NaN                 NaN
# 2152                     NaN                NaN                 NaN
# 14                       NaN                NaN                 NaN
# ...                      ...                ...                 ...
# 29                       NaN                NaN                 NaN
# 2409                     NaN             0.0305                 NaN
# 30                       NaN                NaN                 NaN
# 624       DNA Damage Control                NaN  Genome Maintenance
# 770                      NaN                NaN                 NaN
# 1960                     NaN                NaN                 NaN
# 2410                     NaN                  0                 NaN
# 31                       NaN                NaN                 NaN
# 32                       NaN                NaN                 NaN
# 33                       NaN                NaN                 NaN
# 771                      NaN                NaN                 NaN
# 2412                     NaN              0.386                 NaN
# 34                       NaN                NaN                 NaN
# 625   Chromatin Modification                NaN           Cell Fate
# 2413                     NaN             0.0015                 NaN
# 35                       NaN                NaN                 NaN
# 626                      APC                NaN           Cell Fate
# 1251                     NaN                NaN                 NaN
# 1961                     NaN                NaN                 NaN
# 2415                     NaN              0.172                 NaN
# 36                       NaN                NaN                 NaN
# 1252                     NaN                NaN                 NaN
# 2416                     NaN              0.265                 NaN
# 37                       NaN                NaN                 NaN
# 627          PI3K; RAS; MAPK                NaN       Cell Survival
# 2417                     NaN              0.032                 NaN
# 38                       NaN                NaN                 NaN
# 628       DNA Damage Control                NaN  Genome Maintenance
# 1253                     NaN                NaN                 NaN
# 2418                     NaN             0.0015                 NaN
#
#        driver_type gene_symbol  hgnc_id      pmid  source_name  score
# 0              TSG        ABI1    11320  14993899       Cosmic      1
# 1         Oncogene        ABL1       76  14993899       Cosmic      4
# 614       Oncogene        ABL1       76  23539594   Vogelstein      4
# 2136      Oncogene        ABL1       76  14681372      Uniprot      4
# 2361      Oncogene        ABL1       76  25759023  Rubio-Perez      4
# 2         Oncogene        ABL2       77  14993899       Cosmic      2
# 2362      Oncogene        ABL2       77  25759023  Rubio-Perez      2
# 3         Oncogene       ACKR3    23692  14993899       Cosmic      1
# 4          Unknown       ACSL3     3570  14993899       Cosmic      2
# 2366       Unknown       ACSL3     3570  25759023  Rubio-Perez      2
# 5          Unknown       ACSL6    16496  14993899       Cosmic      2
# 2367           TSG       ACSL6    16496  25759023  Rubio-Perez      2
# 6         Oncogene       ACVR1      171  14993899       Cosmic      1
# 7              TSG      ACVR2A      173  14993899       Cosmic      2
# 2372           TSG      ACVR2A      173  25759023  Rubio-Perez      2
# 8         Oncogene        AFF1     7135  14993899       Cosmic      2
# 2143      Oncogene        AFF1     7135  14681372      Uniprot      2
# 9         Oncogene        AFF3     6473  14993899       Cosmic      1
# 10        Oncogene        AFF4    17869  14993899       Cosmic      3
# 2144      Oncogene        AFF4    17869  14681372      Uniprot      3
# 2375       Unknown        AFF4    17869  25759023  Rubio-Perez      3
# 11        Oncogene       AKAP9      379  14993899       Cosmic      2
# 2379       Unknown       AKAP9      379  25759023  Rubio-Perez      2
# 12        Oncogene        AKT1      391  14993899       Cosmic      4
# 616       Oncogene        AKT1      391  23539594   Vogelstein      4
# 2141      Oncogene        AKT1      391  14681372      Uniprot      4
# 2380      Oncogene        AKT1      391  25759023  Rubio-Perez      4
# 13        Oncogene        AKT2      392  14993899       Cosmic      2
# 2152      Oncogene        AKT2      392  14681372      Uniprot      2
# 14             TSG       ALDH2      404  14993899       Cosmic      1
# ...            ...         ...      ...       ...          ...    ...
# 29        Oncogene        ATIC      794  14993899       Cosmic      2
# 2409           TSG        ATIC      794  25759023  Rubio-Perez      2
# 30             TSG         ATM      795  14993899       Cosmic      5
# 624            TSG         ATM      795  23539594   Vogelstein      5
# 770            TSG         ATM      795  23066107       TSgene      5
# 1960           TSG         ATM      795  14681372      Uniprot      5
# 2410           TSG         ATM      795  25759023  Rubio-Perez      5
# 31    Oncogene/TSG      ATP1A1      799  14993899       Cosmic      1
# 32             TSG      ATP2B3      816  14993899       Cosmic      1
# 33             TSG         ATR      882  14993899       Cosmic      3
# 771            TSG         ATR      882  23066107       TSgene      3
# 2412       Unknown         ATR      882  25759023  Rubio-Perez      3
# 34             TSG        ATRX      886  14993899       Cosmic      3
# 625            TSG        ATRX      886  23539594   Vogelstein      3
# 2413           TSG        ATRX      886  25759023  Rubio-Perez      3
# 35             TSG       AXIN1      903  14993899       Cosmic      5
# 626            TSG       AXIN1      903  23539594   Vogelstein      5
# 1251           TSG       AXIN1      903  23066107       TSgene      5
# 1961           TSG       AXIN1      903  14681372      Uniprot      5
# 2415           TSG       AXIN1      903  25759023  Rubio-Perez      5
# 36             TSG       AXIN2      904  14993899       Cosmic      3
# 1252           TSG       AXIN2      904  23066107       TSgene      3
# 2416           TSG       AXIN2      904  25759023  Rubio-Perez      3
# 37             TSG         B2M      914  14993899       Cosmic      3
# 627            TSG         B2M      914  23539594   Vogelstein      3
# 2417           TSG         B2M      914  25759023  Rubio-Perez      3
# 38             TSG        BAP1      950  14993899       Cosmic      4
# 628            TSG        BAP1      950  23539594   Vogelstein      4
# 1253           TSG        BAP1      950  23066107       TSgene      4
# 2418           TSG        BAP1      950  25759023  Rubio-Perez      4
#
# [100 rows x 9 columns]

# %% [markdown]
# # Save for merging and posting into database with myDrug

# %%
all_genes = {str(k): {'meta_information': v, 
                      'nodes': {'is_driver': 0, 'is_cancer_drug_target': 0},
                      'edges': {}} for k, v in all_genes.items()}

# %%
group_cols = ["hgnc_id"]
exclude_cols = group_cols + ["gene_symbol", "OncodriveROLE_prob", "score"]
groups = df_scored.groupby(group_cols)
for n, g in groups:
    all_genes[str(n)]['meta_information']['driver_information'] = g[[c for c in g.columns if c not in exclude_cols]].to_dict('records')
    all_genes[str(n)]['nodes']['is_driver'] = 1
    all_genes[str(n)]['nodes']['driver_score'] = g[["score"]].mean().loc['score']
    all_genes[str(n)]['nodes']['OncodriveROLE_prob'] = str(g[["OncodriveROLE_prob"]].any().replace({False:None}).loc['OncodriveROLE_prob'])

# %%
all_genes
# Out:
# {'11542': {'edges': {},
#   'meta_information': {'alias_symbol': 'TAFII31|TAFII32|TAFIID32|MGC5067|CGI-137|MGC1603|MGC3647|AD-004',
#    'date_approved_reserved': '1995-07-13',
#    'date_modified': '2015-11-20',
#    'date_symbol_changed': '2001-12-07',
#    'ensembl_gene_id': 'ENSG00000273841',
#    'entrez_id': 6880.0,
#    'gene_family': nan,
#    'gene_symbol': 'TAF9',
#    'hgnc_id': 11542,
#    'location': '5q13.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'TATA-box binding protein associated factor 9',
#    'node_type': 'gene',
#    'prev_symbol': 'TAF2G',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q16594'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '11543': {'edges': {},
#   'meta_information': {'alias_symbol': 'TAFII30',
#    'date_approved_reserved': '1995-05-16',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': '2001-12-07',
#    'ensembl_gene_id': 'ENSG00000166337',
#    'entrez_id': 6881.0,
#    'gene_family': 'SAGA complex',
#    'gene_symbol': 'TAF10',
#    'hgnc_id': 11543,
#    'location': '11p15.4',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'TATA-box binding protein associated factor 10',
#    'node_type': 'gene',
#    'prev_symbol': 'TAF2H|TAF2A',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q12962'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '11540': {'edges': {},
#   'meta_information': {'alias_symbol': 'TAFII70|TAFII80|MGC:8964|TAFII85',
#    'date_approved_reserved': '1995-07-07',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': '2001-12-07',
#    'ensembl_gene_id': 'ENSG00000106290',
#    'entrez_id': 6878.0,
#    'gene_family': nan,
#    'gene_symbol': 'TAF6',
#    'hgnc_id': 11540,
#    'location': '7q22.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'TATA-box binding protein associated factor 6',
#    'node_type': 'gene',
#    'prev_symbol': 'TAF2E',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P49848'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '11541': {'edges': {},
#   'meta_information': {'alias_symbol': 'TAFII55',
#    'date_approved_reserved': '1995-07-07',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': '2001-12-07',
#    'ensembl_gene_id': 'ENSG00000178913',
#    'entrez_id': 6879.0,
#    'gene_family': nan,
#    'gene_symbol': 'TAF7',
#    'hgnc_id': 11541,
#    'location': '5q31.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'TATA-box binding protein associated factor 7',
#    'node_type': 'gene',
#    'prev_symbol': 'TAF2F',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q15545'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '11546': {'edges': {},
#   'meta_information': {'alias_symbol': 'TAFII18',
#    'date_approved_reserved': '1995-07-13',
#    'date_modified': '2015-11-20',
#    'date_symbol_changed': '2001-12-07',
#    'ensembl_gene_id': 'ENSG00000197780',
#    'entrez_id': 6884.0,
#    'gene_family': nan,
#    'gene_symbol': 'TAF13',
#    'hgnc_id': 11546,
#    'location': '1p13.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'TATA-box binding protein associated factor 13',
#    'node_type': 'gene',
#    'prev_symbol': 'TAF2K',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q15543'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '11547': {'edges': {},
#   'meta_information': {'alias_symbol': 'hTAFII68|RBP56|Npl3',
#    'date_approved_reserved': '1999-03-08',
#    'date_modified': '2016-01-15',
#    'date_symbol_changed': '2001-12-07',
#    'driver_information': [{'Core pathway': nan,
#      'Process': nan,
#      'driver_type': 'Unknown',
#      'pmid': '14993899',
#      'source_name': 'Cosmic'},
#     {'Core pathway': nan,
#      'Process': nan,
#      'driver_type': 'Oncogene',
#      'pmid': '14681372',
#      'source_name': 'Uniprot'}],
#    'ensembl_gene_id': 'ENSG00000270647',
#    'entrez_id': 8148.0,
#    'gene_family': 'Zinc fingers RANBP2-type |RNA binding motif containing',
#    'gene_symbol': 'TAF15',
#    'hgnc_id': 11547,
#    'location': '17q12',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'TATA-box binding protein associated factor 15',
#    'node_type': 'gene',
#    'prev_symbol': 'TAF2N',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q92804'},
#   'nodes': {'OncodriveROLE_prob': 'nan',
#    'driver_score': 2.0,
#    'is_cancer_drug_target': 0,
#    'is_driver': 1}},
#  '11544': {'edges': {},
#   'meta_information': {'alias_symbol': 'TAFII28',
#    'date_approved_reserved': '1995-07-13',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': '2001-12-07',
#    'ensembl_gene_id': 'ENSG00000064995',
#    'entrez_id': 6882.0,
#    'gene_family': nan,
#    'gene_symbol': 'TAF11',
#    'hgnc_id': 11544,
#    'location': '6p21.31',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'TATA-box binding protein associated factor 11',
#    'node_type': 'gene',
#    'prev_symbol': 'TAF2I',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q15544'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '11545': {'edges': {},
#   'meta_information': {'alias_symbol': 'TAFII20',
#    'date_approved_reserved': '1995-07-13',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': '2001-12-07',
#    'ensembl_gene_id': 'ENSG00000120656',
#    'entrez_id': 6883.0,
#    'gene_family': 'SAGA complex',
#    'gene_symbol': 'TAF12',
#    'hgnc_id': 11545,
#    'location': '1p35.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'TATA-box binding protein associated factor 12',
#    'node_type': 'gene',
#    'prev_symbol': 'TAF2J',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q16514'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '11548': {'edges': {},
#   'meta_information': {'alias_symbol': 'CT40',
#    'date_approved_reserved': '2000-06-29',
#    'date_modified': '2015-11-20',
#    'date_symbol_changed': '2001-12-07',
#    'ensembl_gene_id': 'ENSG00000102387',
#    'entrez_id': 54457.0,
#    'gene_family': nan,
#    'gene_symbol': 'TAF7L',
#    'hgnc_id': 11548,
#    'location': 'Xq22.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'TATA-box binding protein associated factor 7 like',
#    'node_type': 'gene',
#    'prev_symbol': 'TAF2Q',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q5H9L4'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '11549': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': nan,
#    'date_modified': '2011-03-25',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': nan,
#    'entrez_id': nan,
#    'gene_family': nan,
#    'gene_symbol': 'GTF3BAP1',
#    'hgnc_id': 11549,
#    'location': nan,
#    'locus_group': 'withdrawn',
#    'locus_type': 'withdrawn',
#    'name': 'entry withdrawn',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Entry Withdrawn',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '5988': {'edges': {},
#   'meta_information': {'alias_symbol': 'IL1RRP|IL-1Rrp|CD218a',
#    'date_approved_reserved': '1998-12-17',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000115604',
#    'entrez_id': 8809.0,
#    'gene_family': 'CD molecules|Immunoglobulin like domain containing|Interleukin receptors|TIR domain containing',
#    'gene_symbol': 'IL18R1',
#    'hgnc_id': 5988,
#    'location': '2q12.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 18 receptor 1',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q13478'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '5989': {'edges': {},
#   'meta_information': {'alias_symbol': 'AcPL|CD218b',
#    'date_approved_reserved': '1998-12-17',
#    'date_modified': '2015-08-25',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000115607',
#    'entrez_id': 8807.0,
#    'gene_family': 'CD molecules|Immunoglobulin like domain containing|Interleukin receptors|TIR domain containing',
#    'gene_symbol': 'IL18RAP',
#    'hgnc_id': 5989,
#    'location': '2q12.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 18 receptor accessory protein',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'O95256'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '19399': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2002-10-23',
#    'date_modified': '2015-09-04',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000185220',
#    'entrez_id': 267002.0,
#    'gene_family': 'DNA transposon derived genes',
#    'gene_symbol': 'PGBD2',
#    'hgnc_id': 19399,
#    'location': '1q',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'piggyBac transposable element derived 2',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q6P3X8'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '19398': {'edges': {},
#   'meta_information': {'alias_symbol': 'HUCEP-4|dJ874C20.4|SCAND4',
#    'date_approved_reserved': '2002-10-23',
#    'date_modified': '2015-09-04',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000137338',
#    'entrez_id': 84547.0,
#    'gene_family': 'Scavenger receptor cysteine rich domain containing|DNA transposon derived genes',
#    'gene_symbol': 'PGBD1',
#    'hgnc_id': 19398,
#    'location': '6p22.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'piggyBac transposable element derived 1',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q96JS3'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '5982': {'edges': {},
#   'meta_information': {'alias_symbol': 'IL-17B|ZCYTO7|IL-20|MGC138900|MGC138901|NIRF',
#    'date_approved_reserved': '2000-01-20',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000127743',
#    'entrez_id': 27190.0,
#    'gene_family': 'Interleukins',
#    'gene_symbol': 'IL17B',
#    'hgnc_id': 5982,
#    'location': '5q32',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 17B',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9UHF5'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '5983': {'edges': {},
#   'meta_information': {'alias_symbol': 'IL-17C|CX2|IL-21|MGC126884|MGC138401',
#    'date_approved_reserved': '2000-01-20',
#    'date_modified': '2016-10-11',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000124391',
#    'entrez_id': 27189.0,
#    'gene_family': 'Interleukins',
#    'gene_symbol': 'IL17C',
#    'hgnc_id': 5983,
#    'location': '16q24.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 17C',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9P0M4'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '5980': {'edges': {},
#   'meta_information': {'alias_symbol': 'LCF|IL-16|prIL-16|HsT19289|FLJ42735|FLJ16806',
#    'date_approved_reserved': '1997-07-25',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000172349',
#    'entrez_id': 3603.0,
#    'gene_family': 'Interleukins|PDZ domain containing',
#    'gene_symbol': 'IL16',
#    'hgnc_id': 5980,
#    'location': '15q25.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 16',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q14005'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '5981': {'edges': {},
#   'meta_information': {'alias_symbol': 'IL-17A|IL-17',
#    'date_approved_reserved': '1993-10-25',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': '2006-04-26',
#    'driver_information': [{'Core pathway': nan,
#      'Process': nan,
#      'driver_type': 'TSG',
#      'pmid': '23066107',
#      'source_name': 'TSgene'}],
#    'ensembl_gene_id': 'ENSG00000112115',
#    'entrez_id': 3605.0,
#    'gene_family': 'Interleukins',
#    'gene_symbol': 'IL17A',
#    'hgnc_id': 5981,
#    'location': '6p12.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 17A',
#    'node_type': 'gene',
#    'prev_symbol': 'CTLA8|IL17',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q16552'},
#   'nodes': {'OncodriveROLE_prob': 'nan',
#    'driver_score': 1.0,
#    'is_cancer_drug_target': 0,
#    'is_driver': 1}},
#  '5986': {'edges': {},
#   'meta_information': {'alias_symbol': 'IGIF|IL1F4|IL-1g|IL-18',
#    'date_approved_reserved': '1997-07-25',
#    'date_modified': '2015-07-06',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000150782',
#    'entrez_id': 3606.0,
#    'gene_family': 'Interleukins',
#    'gene_symbol': 'IL18',
#    'hgnc_id': 5986,
#    'location': '11q23.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 18',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q14116'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '5987': {'edges': {},
#   'meta_information': {'alias_symbol': 'IL18BPa',
#    'date_approved_reserved': '1999-05-21',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000137496',
#    'entrez_id': 10068.0,
#    'gene_family': 'Immunoglobulin like domain containing',
#    'gene_symbol': 'IL18BP',
#    'hgnc_id': 5987,
#    'location': '11q13.4',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 18 binding protein',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'O95998'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '5984': {'edges': {},
#   'meta_information': {'alias_symbol': 'IL-22|IL-27|IL-17D|IL27|FLJ30846',
#    'date_approved_reserved': '2000-05-02',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000172458',
#    'entrez_id': 53342.0,
#    'gene_family': 'Interleukins',
#    'gene_symbol': 'IL17D',
#    'hgnc_id': 5984,
#    'location': '13q12.11',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 17D',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q8TAD2'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '5985': {'edges': {},
#   'meta_information': {'alias_symbol': 'hIL-17R|IL-17RA|CDw217|CD217',
#    'date_approved_reserved': '1999-10-29',
#    'date_modified': '2017-03-24',
#    'date_symbol_changed': '2006-04-26',
#    'ensembl_gene_id': 'ENSG00000177663',
#    'entrez_id': 23765.0,
#    'gene_family': 'CD molecules|Interleukin receptors',
#    'gene_symbol': 'IL17RA',
#    'hgnc_id': 5985,
#    'location': '22q11.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 17 receptor A',
#    'node_type': 'gene',
#    'prev_symbol': 'IL17R',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q96F46'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46139': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-04-02',
#    'date_modified': '2013-04-02',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000266863',
#    'entrez_id': 106479266.0,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL123P',
#    'hgnc_id': 46139,
#    'location': '9p24.1',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SL, cytoplasmic 123, pseudogene',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46138': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-04-02',
#    'date_modified': '2013-04-02',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000263529',
#    'entrez_id': 106480954.0,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL122P',
#    'hgnc_id': 46138,
#    'location': '1p35.1',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SL, cytoplasmic 122, pseudogene',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46137': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-04-02',
#    'date_modified': '2013-04-02',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000263974',
#    'entrez_id': 106479265.0,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL121P',
#    'hgnc_id': 46137,
#    'location': '19p13.3',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SL, cytoplasmic 121, pseudogene',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46136': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-04-02',
#    'date_modified': '2013-04-02',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000244169',
#    'entrez_id': 106480953.0,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL120P',
#    'hgnc_id': 46136,
#    'location': '3p26.3',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SL, cytoplasmic 120, pseudogene',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46135': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': nan,
#    'date_modified': '2015-02-12',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': nan,
#    'entrez_id': nan,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL119P',
#    'hgnc_id': 46135,
#    'location': nan,
#    'locus_group': 'withdrawn',
#    'locus_type': 'withdrawn',
#    'name': 'entry withdrawn',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Entry Withdrawn',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46134': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-04-02',
#    'date_modified': '2013-04-02',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000266420',
#    'entrez_id': 106480952.0,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL118P',
#    'hgnc_id': 46134,
#    'location': 'Xq24',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SL, cytoplasmic 118, pseudogene',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46133': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-04-02',
#    'date_modified': '2013-04-02',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000264192',
#    'entrez_id': 106479264.0,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL117P',
#    'hgnc_id': 46133,
#    'location': '2p24.1',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SL, cytoplasmic 117, pseudogene',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46132': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-04-02',
#    'date_modified': '2013-04-02',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000240474',
#    'entrez_id': 106480488.0,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL116P',
#    'hgnc_id': 46132,
#    'location': '20q11.23',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SL, cytoplasmic 116, pseudogene',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46131': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': nan,
#    'date_modified': '2015-02-12',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': nan,
#    'entrez_id': nan,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL115P',
#    'hgnc_id': 46131,
#    'location': nan,
#    'locus_group': 'withdrawn',
#    'locus_type': 'withdrawn',
#    'name': 'entry withdrawn',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Entry Withdrawn',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46130': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': nan,
#    'date_modified': '2015-02-12',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': nan,
#    'entrez_id': nan,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL114P',
#    'hgnc_id': 46130,
#    'location': nan,
#    'locus_group': 'withdrawn',
#    'locus_type': 'withdrawn',
#    'name': 'entry withdrawn',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Entry Withdrawn',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '29237': {'edges': {},
#   'meta_information': {'alias_symbol': 'KIAA1280|BM042',
#    'date_approved_reserved': '2006-02-22',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000047644',
#    'entrez_id': 55841.0,
#    'gene_family': nan,
#    'gene_symbol': 'WWC3',
#    'hgnc_id': 29237,
#    'location': 'Xp22.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'WWC family member 3',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9ULE0'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '270': {'edges': {},
#   'meta_information': {'alias_symbol': 'PARP',
#    'date_approved_reserved': '1986-01-01',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': '2004-08-26',
#    'driver_information': [{'Core pathway': nan,
#      'Process': nan,
#      'driver_type': 'TSG',
#      'pmid': '23066107',
#      'source_name': 'TSgene'}],
#    'ensembl_gene_id': 'ENSG00000143799',
#    'entrez_id': 142.0,
#    'gene_family': 'Zinc fingers|Zinc fingers PARP-type|Poly(ADP-ribose) polymerases',
#    'gene_symbol': 'PARP1',
#    'hgnc_id': 270,
#    'location': '1q42.12',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'poly(ADP-ribose) polymerase 1',
#    'node_type': 'gene',
#    'prev_symbol': 'PPOL|ADPRT',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P09874'},
#   'nodes': {'OncodriveROLE_prob': 'nan',
#    'driver_score': 1.0,
#    'is_cancer_drug_target': 0,
#    'is_driver': 1}},
#  '271': {'edges': {},
#   'meta_information': {'alias_symbol': 'VAULT3|p193|VPARP|VWA5C',
#    'date_approved_reserved': '1998-04-20',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': '2004-08-26',
#    'ensembl_gene_id': 'ENSG00000102699',
#    'entrez_id': 143.0,
#    'gene_family': 'Poly(ADP-ribose) polymerases',
#    'gene_symbol': 'PARP4',
#    'hgnc_id': 271,
#    'location': '13q12.12',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'poly(ADP-ribose) polymerase family member 4',
#    'node_type': 'gene',
#    'prev_symbol': 'ADPRTL1',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9UKK3'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '272': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '1999-05-24',
#    'date_modified': '2015-11-06',
#    'date_symbol_changed': '2004-08-26',
#    'ensembl_gene_id': 'ENSG00000129484',
#    'entrez_id': 10038.0,
#    'gene_family': 'Poly(ADP-ribose) polymerases',
#    'gene_symbol': 'PARP2',
#    'hgnc_id': 272,
#    'location': '14q11.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'poly(ADP-ribose) polymerase 2',
#    'node_type': 'gene',
#    'prev_symbol': 'ADPRTL2',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9UGN5'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '273': {'edges': {},
#   'meta_information': {'alias_symbol': 'ADPRT3|IRT1|hPARP-3|pADPRT-3',
#    'date_approved_reserved': '1999-05-24',
#    'date_modified': '2015-11-06',
#    'date_symbol_changed': '2004-08-26',
#    'ensembl_gene_id': 'ENSG00000041880',
#    'entrez_id': 10039.0,
#    'gene_family': 'Poly(ADP-ribose) polymerases',
#    'gene_symbol': 'PARP3',
#    'hgnc_id': 273,
#    'location': '3p21.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'poly(ADP-ribose) polymerase family member 3',
#    'node_type': 'gene',
#    'prev_symbol': 'ADPRTL3',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9Y6F1'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '274': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '1999-10-29',
#    'date_modified': '2015-11-18',
#    'date_symbol_changed': '2010-09-29',
#    'ensembl_gene_id': 'ENSG00000249263',
#    'entrez_id': 107133524.0,
#    'gene_family': nan,
#    'gene_symbol': 'PARP4P3',
#    'hgnc_id': 274,
#    'location': '22q11.1',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'poly(ADP-ribose) polymerase family member 4 pseudogene 3',
#    'node_type': 'gene',
#    'prev_symbol': 'ADPRTL4',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '275': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '1986-01-01',
#    'date_modified': '2016-03-01',
#    'date_symbol_changed': '2004-08-20',
#    'ensembl_gene_id': 'ENSG00000227105',
#    'entrez_id': 144.0,
#    'gene_family': nan,
#    'gene_symbol': 'PARP1P1',
#    'hgnc_id': 275,
#    'location': '13q34',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'poly(ADP-ribose) polymerase 1 pseudogene 1',
#    'node_type': 'gene',
#    'prev_symbol': 'PPOLP1|ADPRTP1',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '276': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '1986-01-01',
#    'date_modified': '2016-11-09',
#    'date_symbol_changed': '2004-08-20',
#    'ensembl_gene_id': 'ENSG00000258995',
#    'entrez_id': 145.0,
#    'gene_family': nan,
#    'gene_symbol': 'PARP1P2',
#    'hgnc_id': 276,
#    'location': '14q23.2',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'poly(ADP-ribose) polymerase 1 pseudogene 2',
#    'node_type': 'gene',
#    'prev_symbol': 'PPOLP2|ADPRTP2',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '277': {'edges': {},
#   'meta_information': {'alias_symbol': 'ADRA1L1',
#    'date_approved_reserved': '1991-08-19',
#    'date_modified': '2014-11-19',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000120907',
#    'entrez_id': 148.0,
#    'gene_family': 'Adrenoceptors',
#    'gene_symbol': 'ADRA1A',
#    'hgnc_id': 277,
#    'location': '8p21.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'adrenoceptor alpha 1A',
#    'node_type': 'gene',
#    'prev_symbol': 'ADRA1C',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P35348'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '278': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '1991-06-04',
#    'date_modified': '2015-08-24',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000170214',
#    'entrez_id': 147.0,
#    'gene_family': 'Adrenoceptors',
#    'gene_symbol': 'ADRA1B',
#    'hgnc_id': 278,
#    'location': '5q33.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'adrenoceptor alpha 1B',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P35368'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '16704': {'edges': {},
#   'meta_information': {'alias_symbol': 'BNPI|VGLUT1',
#    'date_approved_reserved': '2001-09-27',
#    'date_modified': '2016-02-17',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000104888',
#    'entrez_id': 57030.0,
#    'gene_family': 'Solute carriers',
#    'gene_symbol': 'SLC17A7',
#    'hgnc_id': 16704,
#    'location': '19q13.33',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'solute carrier family 17 member 7',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9P2U7'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '16707': {'edges': {},
#   'meta_information': {'alias_symbol': 'MTAG2|CT25.1a|CT25.1b|MMA-1a|MMA-1b',
#    'date_approved_reserved': '2001-09-28',
#    'date_modified': '2017-04-19',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000198054',
#    'entrez_id': 84677.0,
#    'gene_family': nan,
#    'gene_symbol': 'DSCR8',
#    'hgnc_id': 16707,
#    'location': '21q22.13',
#    'locus_group': 'non-coding RNA',
#    'locus_type': 'RNA, long non-coding',
#    'name': 'Down syndrome critical region 8 (non-protein coding)',
#    'node_type': 'gene',
#    'prev_symbol': 'C21orf65',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q96T75'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '16706': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2002-01-17',
#    'date_modified': '2011-02-10',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': nan,
#    'entrez_id': 140907.0,
#    'gene_family': nan,
#    'gene_symbol': 'SPG19',
#    'hgnc_id': 16706,
#    'location': '9q33-q34',
#    'locus_group': 'phenotype',
#    'locus_type': 'phenotype only',
#    'name': 'spastic paraplegia 19 (autosomal dominant)',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '16701': {'edges': {},
#   'meta_information': {'alias_symbol': 'MLCB|MYL2B|MRLC3|MRCL3',
#    'date_approved_reserved': '2009-03-06',
#    'date_modified': '2015-11-13',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000101608',
#    'entrez_id': 10627.0,
#    'gene_family': 'Myosin light chains|EF-hand domain containing',
#    'gene_symbol': 'MYL12A',
#    'hgnc_id': 16701,
#    'location': '18p11.31',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'myosin light chain 12A',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P19105'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '16700': {'edges': {},
#   'meta_information': {'alias_symbol': 'FOG2|hFOG-2|ZNF89B|ZC2HC11B',
#    'date_approved_reserved': '2002-11-26',
#    'date_modified': '2013-01-10',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000169946',
#    'entrez_id': 23414.0,
#    'gene_family': 'Zinc fingers C2H2-type|Zinc fingers C2HC-type|SET domain containing',
#    'gene_symbol': 'ZFPM2',
#    'hgnc_id': 16700,
#    'location': '8q23',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'zinc finger protein, FOG family member 2',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q8WW38'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '16703': {'edges': {},
#   'meta_information': {'alias_symbol': 'DNPI|VGLUT2',
#    'date_approved_reserved': '2001-09-27',
#    'date_modified': '2016-02-17',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000091664',
#    'entrez_id': 57084.0,
#    'gene_family': 'Solute carriers',
#    'gene_symbol': 'SLC17A6',
#    'hgnc_id': 16703,
#    'location': '11p14.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'solute carrier family 17 member 6',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9P2U8'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '16702': {'edges': {},
#   'meta_information': {'alias_symbol': 'CSN4',
#    'date_approved_reserved': '2001-09-27',
#    'date_modified': '2015-08-24',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000138663',
#    'entrez_id': 51138.0,
#    'gene_family': 'COP9 signalosome ',
#    'gene_symbol': 'COPS4',
#    'hgnc_id': 16702,
#    'location': '4q21.22',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'COP9 signalosome subunit 4',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9BT78'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '12019': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '1990-11-07',
#    'date_modified': '2015-09-08',
#    'date_symbol_changed': '2004-10-15',
#    'ensembl_gene_id': 'ENSG00000172236',
#    'entrez_id': 7177.0,
#    'gene_family': nan,
#    'gene_symbol': 'TPSAB1',
#    'hgnc_id': 12019,
#    'location': '16p13.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'tryptase alpha/beta 1',
#    'node_type': 'gene',
#    'prev_symbol': 'TPSB1|TPS1|TPS2',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q15661'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46705': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-04-02',
#    'date_modified': '2013-04-02',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000263432',
#    'entrez_id': 106481111.0,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL689P',
#    'hgnc_id': 46705,
#    'location': '5q23.2',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SL, cytoplasmic 689, pseudogene',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '12015': {'edges': {},
#   'meta_information': {'alias_symbol': 'TPX',
#    'date_approved_reserved': '1986-01-01',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000115705',
#    'entrez_id': 7173.0,
#    'gene_family': 'Sushi domain containing',
#    'gene_symbol': 'TPO',
#    'hgnc_id': 12015,
#    'location': '2p25.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'thyroid peroxidase',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P07202'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '12014': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '1993-08-25',
#    'date_modified': '2017-03-24',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000137364',
#    'entrez_id': 7172.0,
#    'gene_family': 'Seven-beta-strand methyltransferase motif containing',
#    'gene_symbol': 'TPMT',
#    'hgnc_id': 12014,
#    'location': '6p22.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'thiopurine S-methyltransferase',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P51580'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '12017': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '1991-11-21',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'driver_information': [{'Core pathway': nan,
#      'Process': nan,
#      'driver_type': 'Unknown',
#      'pmid': '14993899',
#      'source_name': 'Cosmic'},
#     {'Core pathway': nan,
#      'Process': nan,
#      'driver_type': 'Oncogene',
#      'pmid': '14681372',
#      'source_name': 'Uniprot'}],
#    'ensembl_gene_id': 'ENSG00000047410',
#    'entrez_id': 7175.0,
#    'gene_family': 'Nucleoporins',
#    'gene_symbol': 'TPR',
#    'hgnc_id': 12017,
#    'location': '1q31.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'translocated promoter region, nuclear basket protein',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P12270'},
#   'nodes': {'OncodriveROLE_prob': 'nan',
#    'driver_score': 2.0,
#    'is_cancer_drug_target': 0,
#    'is_driver': 1}},
#  '12016': {'edges': {},
#   'meta_information': {'alias_symbol': 'TPPII',
#    'date_approved_reserved': '1993-02-23',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000134900',
#    'entrez_id': 7174.0,
#    'gene_family': nan,
#    'gene_symbol': 'TPP2',
#    'hgnc_id': 12016,
#    'location': '13q33.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'tripeptidyl peptidase 2',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P29144'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '12011': {'edges': {},
#   'meta_information': {'alias_symbol': 'DA1|NEM4',
#    'date_approved_reserved': '1991-07-18',
#    'date_modified': '2017-05-24',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000198467',
#    'entrez_id': 7169.0,
#    'gene_family': 'Tropomyosins',
#    'gene_symbol': 'TPM2',
#    'hgnc_id': 12011,
#    'location': '9p13.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'tropomyosin 2',
#    'node_type': 'gene',
#    'prev_symbol': 'AMCD1',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P07951'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '12010': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '1991-07-18',
#    'date_modified': '2017-05-24',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000140416',
#    'entrez_id': 7168.0,
#    'gene_family': 'Tropomyosins',
#    'gene_symbol': 'TPM1',
#    'hgnc_id': 12010,
#    'location': '15q22.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'tropomyosin 1',
#    'node_type': 'gene',
#    'prev_symbol': 'C15orf13|CMH3',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P09493'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '12013': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '1991-07-18',
#    'date_modified': '2017-06-08',
#    'date_symbol_changed': nan,
#    'driver_information': [{'Core pathway': nan,
#      'Process': nan,
#      'driver_type': 'Unknown',
#      'pmid': '14993899',
#      'source_name': 'Cosmic'}],
#    'ensembl_gene_id': 'ENSG00000167460',
#    'entrez_id': 7171.0,
#    'gene_family': 'Tropomyosins',
#    'gene_symbol': 'TPM4',
#    'hgnc_id': 12013,
#    'location': '19p13.12-p13.11',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'tropomyosin 4',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P67936'},
#   'nodes': {'OncodriveROLE_prob': 'nan',
#    'driver_score': 1.0,
#    'is_cancer_drug_target': 0,
#    'is_driver': 1}},
#  '12012': {'edges': {},
#   'meta_information': {'alias_symbol': 'TRK',
#    'date_approved_reserved': '1991-07-18',
#    'date_modified': '2017-05-22',
#    'date_symbol_changed': nan,
#    'driver_information': [{'Core pathway': nan,
#      'Process': nan,
#      'driver_type': 'TSG',
#      'pmid': '14993899',
#      'source_name': 'Cosmic'},
#     {'Core pathway': nan,
#      'Process': nan,
#      'driver_type': 'Oncogene',
#      'pmid': '14681372',
#      'source_name': 'Uniprot'}],
#    'ensembl_gene_id': 'ENSG00000143549',
#    'entrez_id': 7170.0,
#    'gene_family': 'Tropomyosins',
#    'gene_symbol': 'TPM3',
#    'hgnc_id': 12012,
#    'location': '1q21.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'tropomyosin 3',
#    'node_type': 'gene',
#    'prev_symbol': 'NEM1',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P06753'},
#   'nodes': {'OncodriveROLE_prob': 'nan',
#    'driver_score': 2.0,
#    'is_cancer_drug_target': 0,
#    'is_driver': 1}},
#  '17258': {'edges': {},
#   'meta_information': {'alias_symbol': 'KIAA1035|Nna1|CCP1',
#    'date_approved_reserved': '2002-03-27',
#    'date_modified': '2014-11-19',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000135049',
#    'entrez_id': 23287.0,
#    'gene_family': 'M14 carboxypeptidases',
#    'gene_symbol': 'AGTPBP1',
#    'hgnc_id': 17258,
#    'location': '9q21.33',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'ATP/GTP binding protein 1',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9UPW5'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17259': {'edges': {},
#   'meta_information': {'alias_symbol': 'YER112W',
#    'date_approved_reserved': '2003-02-17',
#    'date_modified': '2015-08-25',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000130520',
#    'entrez_id': 25804.0,
#    'gene_family': nan,
#    'gene_symbol': 'LSM4',
#    'hgnc_id': 17259,
#    'location': '19p13.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'LSM4 homolog, U6 small nuclear RNA and mRNA degradation associated',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9Y4Z0'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17250': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': nan,
#    'date_modified': '2005-09-22',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': nan,
#    'entrez_id': nan,
#    'gene_family': nan,
#    'gene_symbol': 'DEFT3P',
#    'hgnc_id': 17250,
#    'location': nan,
#    'locus_group': 'withdrawn',
#    'locus_type': 'withdrawn',
#    'name': 'entry withdrawn',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Entry Withdrawn',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17251': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2009-03-01',
#    'date_modified': '2015-08-25',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000237550',
#    'entrez_id': 388147.0,
#    'gene_family': nan,
#    'gene_symbol': 'RPL9P9',
#    'hgnc_id': 17251,
#    'location': '15q25.2',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'ribosomal protein L9 pseudogene 9',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17252': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2005-05-05',
#    'date_modified': '2011-06-20',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': nan,
#    'entrez_id': 503583.0,
#    'gene_family': 'PRD class homeoboxes and pseudogenes',
#    'gene_symbol': 'ARGFXP1',
#    'hgnc_id': 17252,
#    'location': '5q23.2',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'arginine-fifty homeobox pseudogene 1',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17253': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2006-11-20',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': '2010-03-12',
#    'ensembl_gene_id': 'ENSG00000255883',
#    'entrez_id': 220793.0,
#    'gene_family': nan,
#    'gene_symbol': 'FUNDC2P1',
#    'hgnc_id': 17253,
#    'location': '5q13.2',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'FUN14 domain containing 2 pseudogene 1',
#    'node_type': 'gene',
#    'prev_symbol': 'FUNDC2P',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17254': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': nan,
#    'date_modified': '2014-11-19',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': nan,
#    'entrez_id': nan,
#    'gene_family': nan,
#    'gene_symbol': 'ERVFC1',
#    'hgnc_id': 17254,
#    'location': nan,
#    'locus_group': 'withdrawn',
#    'locus_type': 'withdrawn',
#    'name': 'entry withdrawn',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Entry Withdrawn',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17255': {'edges': {},
#   'meta_information': {'alias_symbol': 'KIAA0166|ROD',
#    'date_approved_reserved': '2001-12-19',
#    'date_modified': '2015-08-28',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000184445',
#    'entrez_id': 9735.0,
#    'gene_family': nan,
#    'gene_symbol': 'KNTC1',
#    'hgnc_id': 17255,
#    'location': '12q24.31',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'kinetochore associated 1',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P50748'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17256': {'edges': {},
#   'meta_information': {'alias_symbol': 'ARP11|ARP3beta',
#    'date_approved_reserved': '2005-05-19',
#    'date_modified': '2017-06-08',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000133627',
#    'entrez_id': 57180.0,
#    'gene_family': 'Actin related proteins',
#    'gene_symbol': 'ACTR3B',
#    'hgnc_id': 17256,
#    'location': '7q36.1-q36.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'ARP3 actin related protein 3 homolog B',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9P1U1'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17257': {'edges': {},
#   'meta_information': {'alias_symbol': 'PDEF|bA375E1.3',
#    'date_approved_reserved': '2003-11-27',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000124664',
#    'entrez_id': 25803.0,
#    'gene_family': 'ETS transcription factor family',
#    'gene_symbol': 'SPDEF',
#    'hgnc_id': 17257,
#    'location': '6p21.31',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
# ...
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '14304': {'edges': {},
#   'meta_information': {'alias_symbol': 'UNC45',
#    'date_approved_reserved': '2002-04-03',
#    'date_modified': '2015-06-19',
#    'date_symbol_changed': '2005-11-17',
#    'ensembl_gene_id': 'ENSG00000141161',
#    'entrez_id': 146862.0,
#    'gene_family': nan,
#    'gene_symbol': 'UNC45B',
#    'hgnc_id': 14304,
#    'location': '17q12',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'unc-45 myosin chaperone B',
#    'node_type': 'gene',
#    'prev_symbol': 'CMYA4',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q8IWX7'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '45965': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-03-19',
#    'date_modified': '2013-03-19',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000240294',
#    'entrez_id': 107063536.0,
#    'gene_family': nan,
#    'gene_symbol': 'RN7SKP241',
#    'hgnc_id': 45965,
#    'location': '10p12.1',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SK small nuclear pseudogene 241',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '45964': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-03-19',
#    'date_modified': '2013-03-19',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000222515',
#    'entrez_id': 106479202.0,
#    'gene_family': nan,
#    'gene_symbol': 'RN7SKP240',
#    'hgnc_id': 45964,
#    'location': '6p22.3',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SK small nuclear pseudogene 240',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '45967': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-03-19',
#    'date_modified': '2013-03-19',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000199975',
#    'entrez_id': 106481819.0,
#    'gene_family': nan,
#    'gene_symbol': 'RN7SKP243',
#    'hgnc_id': 45967,
#    'location': '11q13.4',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SK small nuclear pseudogene 243',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '45966': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-03-19',
#    'date_modified': '2013-03-19',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000251776',
#    'entrez_id': 106480908.0,
#    'gene_family': nan,
#    'gene_symbol': 'RN7SKP242',
#    'hgnc_id': 45966,
#    'location': '9q21.32',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SK small nuclear pseudogene 242',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '45961': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-03-19',
#    'date_modified': '2013-03-19',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000201533',
#    'entrez_id': 106479200.0,
#    'gene_family': nan,
#    'gene_symbol': 'RN7SKP237',
#    'hgnc_id': 45961,
#    'location': '4q31.1',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SK small nuclear pseudogene 237',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '45960': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-03-19',
#    'date_modified': '2015-01-29',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000274662',
#    'entrez_id': 106480906.0,
#    'gene_family': nan,
#    'gene_symbol': 'RN7SKP236',
#    'hgnc_id': 45960,
#    'location': '21q21.2',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SK small nuclear pseudogene 236',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17968': {'edges': {},
#   'meta_information': {'alias_symbol': 'alpha4GnT',
#    'date_approved_reserved': '2004-07-12',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000118017',
#    'entrez_id': 51146.0,
#    'gene_family': 'Alpha 1,4-glycosyltransferases',
#    'gene_symbol': 'A4GNT',
#    'hgnc_id': 17968,
#    'location': '3q22.3',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'alpha-1,4-N-acetylglucosaminyltransferase',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9UNA3'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17969': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2004-07-28',
#    'date_modified': '2016-02-04',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000183185',
#    'entrez_id': 200959.0,
#    'gene_family': 'Gamma-aminobutyric acid type A receptor subunits',
#    'gene_symbol': 'GABRR3',
#    'hgnc_id': 17969,
#    'location': '3q11.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'gamma-aminobutyric acid type A receptor rho3 subunit (gene/pseudogene)',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'A8MPY1'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17966': {'edges': {},
#   'meta_information': {'alias_symbol': 'NY-REN-58|NPHP18',
#    'date_approved_reserved': '2005-12-14',
#    'date_modified': '2016-11-16',
#    'date_symbol_changed': '2014-03-06',
#    'ensembl_gene_id': 'ENSG00000173588',
#    'entrez_id': 51134.0,
#    'gene_family': nan,
#    'gene_symbol': 'CEP83',
#    'hgnc_id': 17966,
#    'location': '12q22',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'centrosomal protein 83',
#    'node_type': 'gene',
#    'prev_symbol': 'CCDC41',
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9Y592'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17967': {'edges': {},
#   'meta_information': {'alias_symbol': 'NY-REN-64',
#    'date_approved_reserved': '2002-09-27',
#    'date_modified': '2017-03-24',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000198001',
#    'entrez_id': 51135.0,
#    'gene_family': nan,
#    'gene_symbol': 'IRAK4',
#    'hgnc_id': 17967,
#    'location': '12q12',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'interleukin 1 receptor associated kinase 4',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q9NWZ3'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17964': {'edges': {},
#   'meta_information': {'alias_symbol': 'MDT1|SDR7C1|ARSDR1',
#    'date_approved_reserved': '2002-12-11',
#    'date_modified': '2015-09-07',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000072042',
#    'entrez_id': 51109.0,
#    'gene_family': 'Short chain dehydrogenase/reductase superfamily',
#    'gene_symbol': 'RDH11',
#    'hgnc_id': 17964,
#    'location': '14q24.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'retinol dehydrogenase 11 (all-trans/9-cis/11-cis)',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q8TC12'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17962': {'edges': {},
#   'meta_information': {'alias_symbol': 'MRGX1',
#    'date_approved_reserved': '2005-05-09',
#    'date_modified': '2015-11-23',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000170255',
#    'entrez_id': 259249.0,
#    'gene_family': 'G protein-coupled receptors, Class A orphans',
#    'gene_symbol': 'MRGPRX1',
#    'hgnc_id': 17962,
#    'location': '11p15.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'MAS related GPR family member X1',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q96LB2'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17963': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2004-07-21',
#    'date_modified': '2011-07-21',
#    'date_symbol_changed': '2008-08-11',
#    'ensembl_gene_id': nan,
#    'entrez_id': 352908.0,
#    'gene_family': 'Parkinson disease associated genes',
#    'gene_symbol': 'PARK11',
#    'hgnc_id': 17963,
#    'location': '2q36-q37',
#    'locus_group': 'phenotype',
#    'locus_type': 'phenotype only',
#    'name': 'Parkinson disease 11 (autosomal recessive, early onset)',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17960': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2009-03-01',
#    'date_modified': '2016-03-03',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000243742',
#    'entrez_id': 113157.0,
#    'gene_family': nan,
#    'gene_symbol': 'RPLP0P2',
#    'hgnc_id': 17960,
#    'location': '11q12.2',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'ribosomal protein lateral stalk subunit P0 pseudogene 2',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '17961': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2002-01-11',
#    'date_modified': '2016-10-05',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000144481',
#    'entrez_id': 79054.0,
#    'gene_family': 'Transient receptor potential cation channels',
#    'gene_symbol': 'TRPM8',
#    'hgnc_id': 17961,
#    'location': '2q37.1',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'transient receptor potential cation channel subfamily M member 8',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'Q7Z2W7'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '49737': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2014-02-13',
#    'date_modified': '2014-02-13',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000249995',
#    'entrez_id': 106481698.0,
#    'gene_family': nan,
#    'gene_symbol': 'ECM1P2',
#    'hgnc_id': 49737,
#    'location': '4p15.33',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'extracellular matrix protein 1 pseudogene 2',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '53432': {'edges': {},
#   'meta_information': {'alias_symbol': 'FLJ22763',
#    'date_approved_reserved': '2017-05-31',
#    'date_modified': '2017-05-31',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000241224',
#    'entrez_id': 401081.0,
#    'gene_family': nan,
#    'gene_symbol': 'C3orf85',
#    'hgnc_id': 53432,
#    'location': '3q13.13',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'chromosome 3 open reading frame 85',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '53433': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2017-05-31',
#    'date_modified': '2017-05-31',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000250821',
#    'entrez_id': 644145.0,
#    'gene_family': nan,
#    'gene_symbol': 'EXOC1L',
#    'hgnc_id': 53433,
#    'location': '4q12',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'exocyst complex component 1 like',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '49847': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2015-03-06',
#    'date_modified': '2015-03-06',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000256537',
#    'entrez_id': 100129361.0,
#    'gene_family': nan,
#    'gene_symbol': 'SMIM10L1',
#    'hgnc_id': 49847,
#    'location': '12p13.2',
#    'locus_group': 'protein-coding gene',
#    'locus_type': 'gene with protein product',
#    'name': 'small integral membrane protein 10 like 1',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': 'P0DMW3'},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '40533': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2011-11-18',
#    'date_modified': '2014-11-18',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000237054',
#    'entrez_id': 100505758.0,
#    'gene_family': nan,
#    'gene_symbol': 'PRMT5-AS1',
#    'hgnc_id': 40533,
#    'location': '14q11.2',
#    'locus_group': 'non-coding RNA',
#    'locus_type': 'RNA, long non-coding',
#    'name': 'PRMT5 antisense RNA 1',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '46224': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-04-02',
#    'date_modified': '2013-04-02',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000264391',
#    'entrez_id': 106480978.0,
#    'gene_family': 'RNAs, 7SL, cytoplasmic',
#    'gene_symbol': 'RN7SL208P',
#    'hgnc_id': 46224,
#    'location': '5q13.3',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'RNA, 7SL, cytoplasmic 208, pseudogene',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '35934': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2009-03-06',
#    'date_modified': '2009-03-11',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': nan,
#    'entrez_id': 392271.0,
#    'gene_family': nan,
#    'gene_symbol': 'RPL32P20',
#    'hgnc_id': 35934,
#    'location': '8q24.22',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'ribosomal protein L32 pseudogene 20',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  '48874': {'edges': {},
#   'meta_information': {'alias_symbol': nan,
#    'date_approved_reserved': '2013-06-20',
#    'date_modified': '2013-06-20',
#    'date_symbol_changed': nan,
#    'ensembl_gene_id': 'ENSG00000257649',
#    'entrez_id': 100996686.0,
#    'gene_family': nan,
#    'gene_symbol': 'METTL7AP1',
#    'hgnc_id': 48874,
#    'location': '12q13.13',
#    'locus_group': 'pseudogene',
#    'locus_type': 'pseudogene',
#    'name': 'methyltransferase like 7A pseudogene 1',
#    'node_type': 'gene',
#    'prev_symbol': nan,
#    'species': 'hsa',
#    'status': 'Approved',
#    'uniprot_ids': nan},
#   'nodes': {'is_cancer_drug_target': 0, 'is_driver': 0}},
#  ...}

# %%
# path_to_save = data_path + "driver_genes_DataFrame.pkl"
# pd.to_pickle(df_scored,path_to_save)

# %%
path_to_save = data_path + "all_genes.pkl"
pd.to_pickle(all_genes,path_to_save)

# %%
path_to_save = data_path + "genes2uniprot.pkl"
pd.to_pickle(genes2uniprot,path_to_save)
